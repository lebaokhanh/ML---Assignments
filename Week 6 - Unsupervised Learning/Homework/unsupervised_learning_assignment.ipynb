# %% [markdown]
# Unsupervised Learning
# ====

# %% [markdown]
# The customer segments data is included as a selection of 440 data points collected on data found from clients of a wholesale distributor in Lisbon, Portugal. More information can be found on the UCI Machine Learning Repository.
#
# Note (m.u.) is shorthand for monetary units.
#
# Features:
# - 1) Fresh: annual spending (m.u.) on fresh products (Continuous)
# - 2) Milk: annual spending (m.u.) on milk products (Continuous)
# - 3) Grocery: annual spending (m.u.) on grocery products (Continuous)
# - 4) Frozen: annual spending (m.u.) on frozen products (Continuous)
# - 5) Detergents_Paper: annual spending (m.u.) on detergents and paper - products (Continuous)
# - 6) Delicatessen: annual spending (m.u.) on and delicatessen products (Continuous)
# - 7) Channel: {Hotel/Restaurant/Cafe - 1, Retail - 2} (Nominal)
# - 8) Region: {Lisbon - 1, Oporto - 2, or Other - 3} (Nominal)

# %% [markdown]
# In this project, you will analyze a dataset containing data on various customers' annual spending amounts (reported in monetary units) of diverse product categories for internal structure. One goal of this project is to best describe the variation in the different types of customers that a wholesale distributor interacts with.

# %% [markdown]
# ## Getting Started

# %%
# Import necessary libraries: pandas, numpy, matplotlib, seaborn
# Your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Read dataset
# For the purposes of this project, the features 'Channel' and 'Region' will be excluded in the analysis — 
# with focus instead on the six product categories recorded for customers.

# import dataset
data = pd.read_csv('./customers.csv')
# data.head()
# drop columns Channel and Region
data_dropped = data.drop(columns=['Channel', 'Region'])

# %% [markdown]
# ## Data Exploration

# %%
# Let's take a look at dataset
# Your code here
data_dropped.head()
# Out:
#    Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicatessen
# 0  12669  9656     7561     214              2674          1338
# 1   7057  9810     9568    1762              3293          1776
# 2   6353  8808     7684    2405              3516          7844
# 3  13265  1196     4221    6404               507          1788
# 4  22615  5410     7198    3915              1777          5185

# %%
# How many observations are in this data set?
# Is there any missing value?
# Your code here
data_dropped.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 440 entries, 0 to 439
# Data columns (total 6 columns):
# Fresh               440 non-null int64
# Milk                440 non-null int64
# Grocery             440 non-null int64
# Frozen              440 non-null int64
# Detergents_Paper    440 non-null int64
# Delicatessen        440 non-null int64
# dtypes: int64(6)
# memory usage: 20.7 KB

# %%
#descriptive statistics of the dataset
# Your code here
data_dropped.describe().T
# Out:
#                   count          mean           std   min      25%     50%  \
# Fresh             440.0  12000.297727  12647.328865   3.0  3127.75  8504.0
# Milk              440.0   5796.265909   7380.377175  55.0  1533.00  3627.0
# Grocery           440.0   7951.277273   9503.162829   3.0  2153.00  4755.5
# Frozen            440.0   3071.931818   4854.673333  25.0   742.25  1526.0
# Detergents_Paper  440.0   2881.493182   4767.854448   3.0   256.75   816.5
# Delicatessen      440.0   1524.870455   2820.105937   3.0   408.25   965.5
#
#                        75%       max
# Fresh             16933.75  112151.0
# Milk               7190.25   73498.0
# Grocery           10655.75   92780.0
# Frozen             3554.25   60869.0
# Detergents_Paper   3922.00   40827.0
# Delicatessen       1820.25   47943.0

# %% [markdown]
# ### Visualization: Purchase Behavior

# %%
# The dataset is composed of six important product categories: 
# 'Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', and 'Delicatessen'. 
# Consider what each category represents in terms of products you could purchase.

# Plot total purchases on each product categories
# Your code here
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('customers.csv')
data = data.drop(columns=['Channel', 'Region'])
data.sum().plot(kind='barh')

# %%
# My code
data_dropped.sum().plot(kind='barh')

# %% [markdown]
# #### What is distribution of Total Purchases of each person

# %%
# Calculate total purchases
# Hint: sum by columns
# Your code here
# Out:
# Distribution of Purchases of each person in percentage: (first 10)
#        Fresh       Milk    Grocery     Frozen  Detergents_Paper  Delicatessen
# 0  37.139423  28.306754  22.165220   0.627345          7.838884      3.922373
# 1  21.213852  29.489569  28.762099   5.296699          9.898996      5.338784
# 2  17.353182  24.059000  20.988801   6.569243          9.603933     21.425840
# 3  48.446003   4.367992  15.415799  23.388481          1.851649      6.530076
# 4  49.056399  11.735358  15.613883   8.492408          3.854664     11.247289
# 5  35.241483  30.921003  19.191314   2.493448          6.720329      5.432422
# 6  45.819006  12.087663  26.355564   1.813716         11.864727      2.059324
# 7  25.676729  16.790324  31.934140   5.654369         11.251143      8.693295
# 8  31.897935  19.514283  33.122927   2.273457          9.179416      4.011982
# 9  12.871287  23.773092  40.463332   2.483820         15.912306      4.496164

# %%
# My code
# data_dropped.sum(axis=1, skipna=True)
col_list = list(data_dropped)
total_list = data_dropped.sum(axis=1, skipna=True)
data_percentage = data_dropped.div(total_list, axis=0) * 100
data_percentage.head(10)
# Out:
#        Fresh       Milk    Grocery     Frozen  Detergents_Paper  Delicatessen
# 0  37.139423  28.306754  22.165220   0.627345          7.838884      3.922373
# 1  21.213852  29.489569  28.762099   5.296699          9.898996      5.338784
# 2  17.353182  24.059000  20.988801   6.569243          9.603933     21.425840
# 3  48.446003   4.367992  15.415799  23.388481          1.851649      6.530076
# 4  49.056399  11.735358  15.613883   8.492408          3.854664     11.247289
# 5  35.241483  30.921003  19.191314   2.493448          6.720329      5.432422
# 6  45.819006  12.087663  26.355564   1.813716         11.864727      2.059324
# 7  25.676729  16.790324  31.934140   5.654369         11.251143      8.693295
# 8  31.897935  19.514283  33.122927   2.273457          9.179416      4.011982
# 9  12.871287  23.773092  40.463332   2.483820         15.912306      4.496164

# %%
# Number of row in dataset
nrows = len(data_dropped.index)
nrows
# Out:
# 440

# %% [markdown]
# #### create list index of 10% lowest spenders

# %%
select_lowest = # Your code here
# Out:
# Int64Index([154,  97,  98, 355, 131, 275, 327, 299, 352, 203, 184, 367,  34,
#             274, 364, 439, 362, 361, 219, 369, 344, 228, 151, 168, 320, 186,
#             206, 350, 375, 250, 392, 238, 378, 433, 359, 192, 290,  95, 391,
#             233, 204, 174, 280, 224],
#            dtype='int64')

# %%
# My code
# calculate how many rows of 10%
rows_ten_percent = int(nrows * 0.1)
select_lowest = total_list.nsmallest(rows_ten_percent).index
select_lowest
# Out:
# Int64Index([154,  97,  98, 355, 131, 275, 327, 299, 352, 203, 184, 367,  34,
#             274, 364, 439, 362, 361, 219, 369, 344, 228, 151, 168, 320, 186,
#             206, 350, 375, 250, 392, 238, 378, 433, 359, 192, 290,  95, 391,
#             233, 204, 174, 280, 224],
#            dtype='int64')

# %% [markdown]
# #### create list index of 10% highest spenders.

# %%
select_highest = # Your code here
# Out:
# Int64Index([202,  24, 171, 165, 239,  45,  12, 201,  71, 163, 331, 196,  28,
#             282,  77, 319, 176, 216, 427, 259,  39,  49, 258, 435, 437,  87,
#             145,  56, 103,  65, 251,  92, 284, 125, 211,  23, 333, 325,  86,
#              61, 183, 181,  47,  85],
#            dtype='int64')

# %%
# My code
select_highest = total_list.nlargest(rows_ten_percent).index
select_highest
# Out:
# Int64Index([ 85,  47, 181, 183,  61,  86, 325, 333,  23, 211, 125, 284,  92,
#             251,  65, 103,  56, 145,  87, 437, 435, 258,  49,  39, 259, 427,
#             216, 176, 319,  77, 282,  28, 196, 331, 163,  71, 201,  12,  45,
#             239, 165, 171,  24, 202],
#            dtype='int64')

# %% [markdown]
# #### how the 10% lowest spenders compare to the 10% highest spenders.

# %%
# Using select_lowest index to select 10% lowest spenders 
lowest = # Your code here
lowest['Spending'] = 'Low'
# Out:
#          Fresh       Milk    Grocery     Frozen  Detergents_Paper  \
# 154  68.805310   6.084071  15.154867   8.296460          0.774336
# 97   18.674699  11.770158  28.266914  35.866543          2.502317
# 98   20.315024   4.523425  31.421648  36.147011          2.261712
# 355   5.451937  20.860832  57.733142   7.030129          5.279770
# 131  56.327078  15.790885   8.418231   9.276139          1.876676
#
#      Delicatessen Spending
# 154      0.884956      Low
# 97       2.919370      Low
# 98       5.331179      Low
# 355      3.644189      Low
# 131      8.310992      Low

# %%
# My code
lowest = pd.DataFrame(data_dropped, index=select_lowest)
lowest['Spending'] = 'Low'
lowest.head()
# Out:
#      Fresh  Milk  Grocery  Frozen  Detergents_Paper  Delicatessen Spending
# 154    622    55      137      75                 7             8      Low
# 97     403   254      610     774                54            63      Low
# 98     503   112      778     895                56           132      Low
# 355    190   727     2012     245               184           127      Low
# 131   2101   589      314     346                70           310      Low

# %%
# Using select_highest index to select 10% highest spenders 
highest = # Your code here
highest['Spending'] = 'High'
# Out:
#          Fresh       Milk    Grocery    Frozen  Detergents_Paper  \
# 202  43.168388  19.675248  16.254732  8.675471          0.486443
# 24   38.132682  16.460684  23.222765  4.908234          7.546725
# 171   0.324929  42.016506  32.193917  1.057642         14.252989
# 165  25.170057  20.395564  32.009414  7.132725         11.457494
# 239  76.400753   4.129466   6.079179  8.434278          1.331982
#
#      Delicatessen Spending
# 202     11.739719     High
# 24       9.728911     High
# 171     10.154016     High
# 165      3.834746     High
# 239      3.624342     High

# %%
# My code
highest = pd.DataFrame(data_dropped, index=select_highest)
highest['Spending'] = 'High'
highest.head()
# Out:
#       Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicatessen Spending
# 85    16117  46197    92780    1026             40827          2944     High
# 47    44466  54259    55571    7782             24171          6465     High
# 181  112151  29627    18148   16745              4948          8550     High
# 183   36847  43950    20170   36534               239         47943     High
# 61    35942  38369    59598    3254             26701          2017     High

# %%
# Merge 10 highest and 10 lowest to high_and_low dataset
high_and_low = pd.concat([highest, lowest])
high_and_low.head(10)
# Out:
#       Fresh   Milk  Grocery  Frozen  Detergents_Paper  Delicatessen Spending
# 85    16117  46197    92780    1026             40827          2944     High
# 47    44466  54259    55571    7782             24171          6465     High
# 181  112151  29627    18148   16745              4948          8550     High
# 183   36847  43950    20170   36534               239         47943     High
# 61    35942  38369    59598    3254             26701          2017     High
# 86    22925  73498    32114     987             20070           903     High
# 325   32717  16784    13626   60869              1272          5609     High
# 333    8565   4980    67298     131             38102          1215     High
# 23    26373  36423    22019    5154              4337         16523     High
# 211   12119  28326    39694    4736             19410          2870     High

# %%
# Use boxplot with param: by='Spending', figsize=(12, 8), layout=(2, 3)
# Your code here

# %%
# my code
from matplotlib.gridspec import GridSpec
plt.figure(figsize=(12, 8))
gses = GridSpec(2, 3)
column_name = ['Fresh', 'Milk', 'Grocery', 'Frozen', 'Detergents_Paper', 'Delicatessen']
for i, gs in enumerate(gses):
    ax = plt.subplot(gs)
#     high_and_low.boxplot(column='Milk', by='Spending')
    sns.boxplot(data=high_and_low,
                x='Spending',
                y=column_name[i]
               )
plt.show()

# %% [markdown]
# The main difference between purchasing habits in groups appears on variables **Frozen, Detergents_Paper and Delicatessen**. Clients that spend more tend to buy more (relatively speaking) on Detergents and Paper and less on Frozen Goods and Delicatessen than clients spending less.

# %% [markdown]
# ## PCA

# %% [markdown]
# **Normalization** is important in **PCA** since it is a variance maximizing exercise. It projects your original data onto directions which maximize the variance. So we need to scale our data first.

# %%
# Import scale from sklearn.preprocessing
from sklearn.preprocessing import scale

# Scale data and called it as X
X = pd.DataFrame(scale(data_dropped), index=data_dropped.index, columns=data_dropped.columns)
X.head()
# Out:
# /Users/khanhle/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:5: DataConversionWarning: Data with input dtype int64 were all converted to float64 by the scale function.
#   """
#       Fresh      Milk   Grocery    Frozen  Detergents_Paper  Delicatessen
# 0  0.052933  0.523568 -0.041115 -0.589367         -0.043569     -0.066339
# 1 -0.391302  0.544458  0.170318 -0.270136          0.086407      0.089151
# 2 -0.447029  0.408538 -0.028157 -0.137536          0.133232      2.243293
# 3  0.100111 -0.624020 -0.392977  0.687144         -0.498588      0.093411
# 4  0.840239 -0.052396 -0.079356  0.173859         -0.231918      1.299347

# %%
# Import PCA
# Your code here
from sklearn.decomposition import PCA

# Apply PCA by fitting the scaled data with the same number of dimensions as features
pca = PCA(n_components=6)
pca.fit(X)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=6, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)

# %%
# pca_loadings
pca_loadings = pd.DataFrame(pca.components_.T, index=X.columns,
                            columns=['V1', 'V2', 'V3', 'V4', 'V5', 'V6'])

# Transform X using the PCA fit above
pca_data = pd.DataFrame(pca.fit_transform(X),
                        columns=['PC1', 'PC2', 'PC3', 'PC4', 'PC5', 'PC6'],
                        index=X.index)

# %%
# pca.components_.T
# pca_loadings
pca_data
# Out:
#           PC1       PC2       PC3       PC4       PC5       PC6
# 0    0.193291 -0.305100 -0.140878 -0.486432  0.495281 -0.007414
# 1    0.434420 -0.328413  0.319007 -0.178830  0.365579  0.054572
# 2    0.811143  0.815096  1.523416 -1.254082 -0.379054 -0.277539
# 3   -0.778648  0.652754  0.163012  0.380060 -0.276138  0.060718
# 4    0.166287  1.271434  0.066279 -0.826227 -0.394211 -0.026825
# 5   -0.156170 -0.295141  0.147612 -0.418288  0.479455 -0.053940
# 6   -0.335288 -0.525003 -0.303195 -0.192047 -0.153340 -0.063923
# 7    0.140586 -0.230993  0.390010 -0.301346 -0.265691  0.042529
# 8   -0.517320 -0.659363  0.182510 -0.190881  0.025707  0.091596
# 9    1.592109 -0.741011  0.210297 -0.080013 -0.122742  0.157314
# 10   0.638086 -0.401825  0.495674  0.501710 -0.430390 -0.047397
# 11  -0.927693 -0.219287 -0.258030 -0.149016 -0.123831  0.128848
# 12   0.991362  0.685911 -1.127060 -1.084998  0.316766  0.027015
# 13   0.850247 -0.085692 -0.949699  0.223432 -0.392516 -0.020247
# 14   0.845044  0.154724 -0.875562 -0.722132  0.014152 -0.061912
# 15  -0.951585 -0.495908 -0.129396 -0.233075 -0.104716  0.029571
# 16   0.557559 -1.026123  0.445792 -0.103311  0.193156  0.119860
# 17  -0.352539  0.207076  0.992945 -0.968852  0.092630 -0.075816
# 18   0.316579  0.442066 -0.165179 -0.572092 -0.209061  0.116850
# 19  -0.323756 -0.703587 -0.041391 -0.058352 -0.249938  0.231498
# 20  -0.320001  0.156628 -0.273352 -0.584038 -0.064425 -0.183743
# 21  -1.118447 -0.230528  0.346475  0.258701 -0.046541 -0.022498
# 22  -0.176695  2.143717 -0.461523  0.081654 -0.708320 -0.323001
# 23   4.685654  3.598678  1.990551 -3.031279  1.120418  0.254227
# 24   1.245042  1.055660  0.020843 -0.982027 -0.377018  0.049754
# 25  -0.154114 -0.522894 -0.687227 -0.190457 -0.079299 -0.143995
# 26  -1.039624 -0.036480  0.103396  0.092682 -0.100052  0.042253
# 27  -1.097527 -0.242982 -0.334089 -0.351417 -0.080070  0.082024
# 28   3.122092 -0.330075  0.872436 -0.643365  0.271401  0.399576
# 29  -0.779940  1.073173 -2.116771 -0.821553 -0.141216 -0.195453
# ..        ...       ...       ...       ...       ...       ...
# 410 -0.601631 -0.305588  0.389059 -0.269074 -0.240240 -0.080474
# 411 -0.574286  0.087397  1.215039 -0.733180 -0.207797 -0.003650
# 412 -0.081306 -1.232105  0.312590  0.117069 -0.173204  0.419369
# 413 -0.163944  1.849839  1.228387  2.223585 -0.080740  0.136281
# 414 -0.861319 -0.023997  0.324568  0.699691 -0.005570 -0.031857
# 415  0.133114 -0.327081  0.257853 -0.181918 -0.053921 -0.043453
# 416  0.907636 -0.887245  0.207025  0.005196  0.305863 -0.312647
# 417  0.144041 -0.797321  0.205266 -0.148868 -0.085442  0.191434
# 418  1.159522 -1.319010  0.271667  0.119741 -0.182503  0.303502
# 419 -0.685108 -0.304136  0.197538 -0.414125  0.083751 -0.220793
# 420  0.666809 -1.021118  0.171304 -0.108668 -0.453910 -0.128213
# 421  0.077017 -0.055581 -0.388013 -0.426396 -0.217747 -0.002937
# 422 -0.782023  0.376151 -1.003157 -0.624690 -0.240498 -0.011735
# 423 -0.559320 -0.089881 -0.540038 -0.306130  0.035500 -0.070785
# 424 -0.034866 -0.413841 -0.720541 -0.097467 -0.356222  0.319683
# 425 -0.738136  1.773376  0.680197  1.769630 -0.112439 -0.037545
# 426  0.941276 -0.053511 -0.108129  0.025682 -0.015810  0.135825
# 427  0.529385  2.536284 -0.660017  1.373497  1.376990  0.020502
# 428 -0.553026 -0.542888  0.413114  0.156660  0.439761  0.121009
# 429 -0.845501 -0.176852  0.385213 -0.709074 -0.187670  0.084807
# 430  0.093056 -0.594927  0.549109 -0.319235 -0.283752  1.055708
# 431 -0.269326  1.283388  0.673559  1.639066  0.123753 -0.017033
# 432 -0.815141 -0.094405 -0.856455 -0.430600 -0.195484  0.017725
# 433 -0.932563 -0.419578  0.698557 -0.172805  0.161239 -0.078491
# 434 -0.264539 -0.220207 -0.520857 -0.327681 -0.102924  0.098959
# 435  0.870602  2.220845 -0.605500  1.049263  0.423781  0.869495
# 436 -0.902520  1.676916 -1.418980 -0.572274 -0.257026 -0.226535
# 437  3.465704 -1.039838 -0.713161  0.033408 -0.538768 -0.085349
# 438 -0.918023 -0.030047  0.258408 -0.524578 -0.093215 -0.028943
# 439 -1.105137 -0.861338  0.305154 -0.114377  0.109903  0.028978
#
# [440 rows x 6 columns]

# %% [markdown]
# ### Analyzing PCA Samples

# %% [markdown]
# ### Visualizing a Biplot

# %%
def biplot(origin_data, reduced_data, pca):
    '''
    Produce a biplot that shows a scatterplot of the reduced
    data and the projections of the original features.
    
    origin_data: original data, before transformation.
               Needs to be a pandas dataframe with valid column names
    reduced_data: the reduced data (the first two dimensions are plotted)
    pca: pca object that contains the components_ attribute

    return: a matplotlib AxesSubplot object (for any additional customization)
    
    This procedure is inspired by the script:
    https://github.com/teddyroland/python-biplot
    '''

    fig, ax = plt.subplots(figsize = (14,8))
    # scatterplot of the reduced data    
    ax.scatter(x=reduced_data.loc[:, 'PC1'], y=reduced_data.loc[:, 'PC2'], 
        facecolors='b', edgecolors='b', s=70, alpha=0.5)
    
    feature_vectors = pca.components_.T

    # we use scaling factors to make the arrows easier to see
    arrow_size, text_pos = 7.0, 8.0,

    # projections of the original features
    for i, v in enumerate(feature_vectors):
        ax.arrow(0, 0, arrow_size*v[0], arrow_size*v[1], 
                  head_width=0.2, head_length=0.2, linewidth=2, color='red')
        ax.text(v[0]*text_pos, v[1]*text_pos, origin_data.columns[i], color='black', 
                 ha='center', va='center', fontsize=18)

    ax.set_xlabel("Dimension 1", fontsize=14)
    ax.set_ylabel("Dimension 2", fontsize=14)
    ax.set_title("PC plane with original feature projections.", fontsize=16);
    return ax

# %%
# Using provided biplot function to make a biplot
# Your code here

# %%
# my code
biplot(X, pca_data, pca)

# %% [markdown]
# ### Choosing the number of components
# A vital part of using PCA in practice is the ability to estimate how many components are needed to describe the data. This can be determined by looking at the cumulative explained variance ratio as a function of the number of components:

# %%
# Your code here

# %%
#my code
sns.set_style('whitegrid')
pca = PCA().fit(X)

plt.figure(figsize=(16, 9))
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### K-Means

# %% [markdown]
# To use K-Means algorithms we need to define K value first. One way to choose K value, we use elbow algorithms

# %%
# Import KMeans from sklearn
# Your code here

# Choose the range of k value we want to test (1 - 20)
# k_values = # Your code here

# For each value of K, we create a KMeans model and save in k_mean_models
# k_mean_models = # Your code here

# For each Models, we fit with scaled data and calculate score
# scores = # Your code here

norm_scores = [score/max(scores) for score in scores]

plt.plot(k_values, norm_scores, '-o')
plt.xlabel('k')
plt.ylabel('score');

# %%
# my code
from sklearn.cluster import KMeans

k_values = range(1, 20)

k_mean_models = [KMeans(n_clusters=k_value) for k_value in k_values]

scores = [k_mean_model.fit(data_dropped).score(data_dropped) for k_mean_model in k_mean_models]

norm_scores = [score/max(scores) for score in scores]

plt.plot(k_values, norm_scores, '-o')
plt.xlabel('k')
plt.ylabel('score')
# Out:
# Text(0, 0.5, 'score')

# %% [markdown]
# ### Hierarchical

# %%
# Import dendrogram, linkage from scipy.cluster.hierarchy
# Your code here
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
# generate the linkage matrix
# Your code here
Z = linkage(X, 'ward')

# %%
# calculate full dendrogram
# Hint: refer to lecture notebook
# Your code here

# %%
# calculate full dendrogram
# my code here
fig = plt.figure(figsize=(25, 10))

plt.yticks(fontsize=10)
plt.title("Hierarchical Cluster", fontsize=60)
dendrogram(
    Z,
    leaf_font_size=10
)
# Out:
# {'icoord': [[25.0, 25.0, 35.0, 35.0],
#   [15.0, 15.0, 30.0, 30.0],
#   [45.0, 45.0, 55.0, 55.0],
#   [22.5, 22.5, 50.0, 50.0],
#   [5.0, 5.0, 36.25, 36.25],
#   [65.0, 65.0, 75.0, 75.0],
#   [95.0, 95.0, 105.0, 105.0],
#   [85.0, 85.0, 100.0, 100.0],
#   [115.0, 115.0, 125.0, 125.0],
#   [135.0, 135.0, 145.0, 145.0],
#   [120.0, 120.0, 140.0, 140.0],
#   [92.5, 92.5, 130.0, 130.0],
#   [70.0, 70.0, 111.25, 111.25],
#   [175.0, 175.0, 185.0, 185.0],
#   [165.0, 165.0, 180.0, 180.0],
#   [215.0, 215.0, 225.0, 225.0],
#   [205.0, 205.0, 220.0, 220.0],
#   [195.0, 195.0, 212.5, 212.5],
#   [172.5, 172.5, 203.75, 203.75],
#   [155.0, 155.0, 188.125, 188.125],
#   [90.625, 90.625, 171.5625, 171.5625],
#   [255.0, 255.0, 265.0, 265.0],
#   [245.0, 245.0, 260.0, 260.0],
#   [235.0, 235.0, 252.5, 252.5],
#   [285.0, 285.0, 295.0, 295.0],
#   [275.0, 275.0, 290.0, 290.0],
#   [305.0, 305.0, 315.0, 315.0],
#   [282.5, 282.5, 310.0, 310.0],
#   [243.75, 243.75, 296.25, 296.25],
#   [131.09375, 131.09375, 270.0, 270.0],
#   [335.0, 335.0, 345.0, 345.0],
#   [365.0, 365.0, 375.0, 375.0],
#   [355.0, 355.0, 370.0, 370.0],
#   [340.0, 340.0, 362.5, 362.5],
#   [325.0, 325.0, 351.25, 351.25],
#   [405.0, 405.0, 415.0, 415.0],
#   [395.0, 395.0, 410.0, 410.0],
#   [435.0, 435.0, 445.0, 445.0],
#   [425.0, 425.0, 440.0, 440.0],
#   [455.0, 455.0, 465.0, 465.0],
#   [432.5, 432.5, 460.0, 460.0],
#   [402.5, 402.5, 446.25, 446.25],
#   [385.0, 385.0, 424.375, 424.375],
#   [338.125, 338.125, 404.6875, 404.6875],
#   [475.0, 475.0, 485.0, 485.0],
#   [515.0, 515.0, 525.0, 525.0],
#   [505.0, 505.0, 520.0, 520.0],
#   [535.0, 535.0, 545.0, 545.0],
#   [512.5, 512.5, 540.0, 540.0],
#   [495.0, 495.0, 526.25, 526.25],
#   [555.0, 555.0, 565.0, 565.0],
#   [575.0, 575.0, 585.0, 585.0],
#   [595.0, 595.0, 605.0, 605.0],
#   [615.0, 615.0, 625.0, 625.0],
#   [645.0, 645.0, 655.0, 655.0],
#   [635.0, 635.0, 650.0, 650.0],
#   [620.0, 620.0, 642.5, 642.5],
#   [600.0, 600.0, 631.25, 631.25],
#   [580.0, 580.0, 615.625, 615.625],
#   [560.0, 560.0, 597.8125, 597.8125],
#   [510.625, 510.625, 578.90625, 578.90625],
#   [480.0, 480.0, 544.765625, 544.765625],
#   [371.40625, 371.40625, 512.3828125, 512.3828125],
#   [665.0, 665.0, 675.0, 675.0],
#   [685.0, 685.0, 695.0, 695.0],
#   [705.0, 705.0, 715.0, 715.0],
#   [690.0, 690.0, 710.0, 710.0],
#   [670.0, 670.0, 700.0, 700.0],
#   [745.0, 745.0, 755.0, 755.0],
#   [735.0, 735.0, 750.0, 750.0],
#   [725.0, 725.0, 742.5, 742.5],
#   [685.0, 685.0, 733.75, 733.75],
#   [775.0, 775.0, 785.0, 785.0],
#   [795.0, 795.0, 805.0, 805.0],
#   [815.0, 815.0, 825.0, 825.0],
#   [845.0, 845.0, 855.0, 855.0],
#   [835.0, 835.0, 850.0, 850.0],
#   [820.0, 820.0, 842.5, 842.5],
#   [800.0, 800.0, 831.25, 831.25],
#   [780.0, 780.0, 815.625, 815.625],
#   [765.0, 765.0, 797.8125, 797.8125],
#   [709.375, 709.375, 781.40625, 781.40625],
#   [441.89453125, 441.89453125, 745.390625, 745.390625],
#   [865.0, 865.0, 875.0, 875.0],
#   [885.0, 885.0, 895.0, 895.0],
#   [870.0, 870.0, 890.0, 890.0],
#   [905.0, 905.0, 915.0, 915.0],
#   [925.0, 925.0, 935.0, 935.0],
#   [955.0, 955.0, 965.0, 965.0],
#   [945.0, 945.0, 960.0, 960.0],
#   [930.0, 930.0, 952.5, 952.5],
#   [910.0, 910.0, 941.25, 941.25],
#   [880.0, 880.0, 925.625, 925.625],
#   [995.0, 995.0, 1005.0, 1005.0],
#   [985.0, 985.0, 1000.0, 1000.0],
#   [975.0, 975.0, 992.5, 992.5],
#   [1015.0, 1015.0, 1025.0, 1025.0],
#   [1045.0, 1045.0, 1055.0, 1055.0],
#   [1035.0, 1035.0, 1050.0, 1050.0],
#   [1020.0, 1020.0, 1042.5, 1042.5],
#   [983.75, 983.75, 1031.25, 1031.25],
#   [902.8125, 902.8125, 1007.5, 1007.5],
#   [1075.0, 1075.0, 1085.0, 1085.0],
#   [1065.0, 1065.0, 1080.0, 1080.0],
#   [1115.0, 1115.0, 1125.0, 1125.0],
#   [1105.0, 1105.0, 1120.0, 1120.0],
#   [1095.0, 1095.0, 1112.5, 1112.5],
#   [1072.5, 1072.5, 1103.75, 1103.75],
#   [1145.0, 1145.0, 1155.0, 1155.0],
#   [1135.0, 1135.0, 1150.0, 1150.0],
#   [1165.0, 1165.0, 1175.0, 1175.0],
#   [1142.5, 1142.5, 1170.0, 1170.0],
#   [1185.0, 1185.0, 1195.0, 1195.0],
#   [1215.0, 1215.0, 1225.0, 1225.0],
#   [1205.0, 1205.0, 1220.0, 1220.0],
#   [1190.0, 1190.0, 1212.5, 1212.5],
#   [1245.0, 1245.0, 1255.0, 1255.0],
#   [1235.0, 1235.0, 1250.0, 1250.0],
#   [1275.0, 1275.0, 1285.0, 1285.0],
#   [1265.0, 1265.0, 1280.0, 1280.0],
#   [1295.0, 1295.0, 1305.0, 1305.0],
#   [1315.0, 1315.0, 1325.0, 1325.0],
#   [1300.0, 1300.0, 1320.0, 1320.0],
#   [1272.5, 1272.5, 1310.0, 1310.0],
#   [1242.5, 1242.5, 1291.25, 1291.25],
#   [1201.25, 1201.25, 1266.875, 1266.875],
#   [1156.25, 1156.25, 1234.0625, 1234.0625],
#   [1345.0, 1345.0, 1355.0, 1355.0],
#   [1335.0, 1335.0, 1350.0, 1350.0],
#   [1395.0, 1395.0, 1405.0, 1405.0],
#   [1385.0, 1385.0, 1400.0, 1400.0],
#   [1375.0, 1375.0, 1392.5, 1392.5],
#   [1415.0, 1415.0, 1425.0, 1425.0],
#   [1435.0, 1435.0, 1445.0, 1445.0],
#   [1455.0, 1455.0, 1465.0, 1465.0],
#   [1440.0, 1440.0, 1460.0, 1460.0],
#   [1420.0, 1420.0, 1450.0, 1450.0],
#   [1383.75, 1383.75, 1435.0, 1435.0],
#   [1365.0, 1365.0, 1409.375, 1409.375],
#   [1342.5, 1342.5, 1387.1875, 1387.1875],
#   [1195.15625, 1195.15625, 1364.84375, 1364.84375],
#   [1088.125, 1088.125, 1280.0, 1280.0],
#   [955.15625, 955.15625, 1184.0625, 1184.0625],
#   [1475.0, 1475.0, 1485.0, 1485.0],
#   [1495.0, 1495.0, 1505.0, 1505.0],
#   [1480.0, 1480.0, 1500.0, 1500.0],
#   [1515.0, 1515.0, 1525.0, 1525.0],
#   [1555.0, 1555.0, 1565.0, 1565.0],
#   [1545.0, 1545.0, 1560.0, 1560.0],
#   [1535.0, 1535.0, 1552.5, 1552.5],
#   [1575.0, 1575.0, 1585.0, 1585.0],
#   [1543.75, 1543.75, 1580.0, 1580.0],
#   [1520.0, 1520.0, 1561.875, 1561.875],
#   [1490.0, 1490.0, 1540.9375, 1540.9375],
#   [1069.609375, 1069.609375, 1515.46875, 1515.46875],
#   [593.642578125, 593.642578125, 1292.5390625, 1292.5390625],
#   [200.546875, 200.546875, 943.0908203125, 943.0908203125],
#   [1595.0, 1595.0, 1605.0, 1605.0],
#   [1635.0, 1635.0, 1645.0, 1645.0],
#   [1625.0, 1625.0, 1640.0, 1640.0],
#   [1615.0, 1615.0, 1632.5, 1632.5],
#   [1600.0, 1600.0, 1623.75, 1623.75],
#   [1655.0, 1655.0, 1665.0, 1665.0],
#   [1685.0, 1685.0, 1695.0, 1695.0],
#   [1675.0, 1675.0, 1690.0, 1690.0],
#   [1660.0, 1660.0, 1682.5, 1682.5],
#   [1715.0, 1715.0, 1725.0, 1725.0],
#   [1705.0, 1705.0, 1720.0, 1720.0],
#   [1745.0, 1745.0, 1755.0, 1755.0],
#   [1735.0, 1735.0, 1750.0, 1750.0],
#   [1765.0, 1765.0, 1775.0, 1775.0],
#   [1785.0, 1785.0, 1795.0, 1795.0],
#   [1770.0, 1770.0, 1790.0, 1790.0],
#   [1742.5, 1742.5, 1780.0, 1780.0],
#   [1712.5, 1712.5, 1761.25, 1761.25],
#   [1671.25, 1671.25, 1736.875, 1736.875],
#   [1815.0, 1815.0, 1825.0, 1825.0],
#   [1805.0, 1805.0, 1820.0, 1820.0],
#   [1835.0, 1835.0, 1845.0, 1845.0],
#   [1812.5, 1812.5, 1840.0, 1840.0],
#   [1855.0, 1855.0, 1865.0, 1865.0],
#   [1875.0, 1875.0, 1885.0, 1885.0],
#   [1860.0, 1860.0, 1880.0, 1880.0],
#   [1895.0, 1895.0, 1905.0, 1905.0],
#   [1915.0, 1915.0, 1925.0, 1925.0],
#   [1900.0, 1900.0, 1920.0, 1920.0],
#   [1870.0, 1870.0, 1910.0, 1910.0],
#   [1826.25, 1826.25, 1890.0, 1890.0],
#   [1704.0625, 1704.0625, 1858.125, 1858.125],
#   [1611.875, 1611.875, 1781.09375, 1781.09375],
#   [1955.0, 1955.0, 1965.0, 1965.0],
#   [1975.0, 1975.0, 1985.0, 1985.0],
#   [1960.0, 1960.0, 1980.0, 1980.0],
#   [1945.0, 1945.0, 1970.0, 1970.0],
#   [2015.0, 2015.0, 2025.0, 2025.0],
#   [2035.0, 2035.0, 2045.0, 2045.0],
#   [2020.0, 2020.0, 2040.0, 2040.0],
#   [2005.0, 2005.0, 2030.0, 2030.0],
#   [2065.0, 2065.0, 2075.0, 2075.0],
#   [2055.0, 2055.0, 2070.0, 2070.0],
#   [2017.5, 2017.5, 2062.5, 2062.5],
#   [1995.0, 1995.0, 2040.0, 2040.0],
#   [1957.5, 1957.5, 2017.5, 2017.5],
#   [1935.0, 1935.0, 1987.5, 1987.5],
#   [2095.0, 2095.0, 2105.0, 2105.0],
#   [2085.0, 2085.0, 2100.0, 2100.0],
#   [2125.0, 2125.0, 2135.0, 2135.0],
#   [2115.0, 2115.0, 2130.0, 2130.0],
#   [2092.5, 2092.5, 2122.5, 2122.5],
#   [2145.0, 2145.0, 2155.0, 2155.0],
#   [2165.0, 2165.0, 2175.0, 2175.0],
#   [2150.0, 2150.0, 2170.0, 2170.0],
#   [2185.0, 2185.0, 2195.0, 2195.0],
#   [2215.0, 2215.0, 2225.0, 2225.0],
#   [2205.0, 2205.0, 2220.0, 2220.0],
#   [2190.0, 2190.0, 2212.5, 2212.5],
#   [2160.0, 2160.0, 2201.25, 2201.25],
#   [2107.5, 2107.5, 2180.625, 2180.625],
#   [2245.0, 2245.0, 2255.0, 2255.0],
#   [2235.0, 2235.0, 2250.0, 2250.0],
#   [2265.0, 2265.0, 2275.0, 2275.0],
#   [2285.0, 2285.0, 2295.0, 2295.0],
#   [2270.0, 2270.0, 2290.0, 2290.0],
#   [2242.5, 2242.5, 2280.0, 2280.0],
#   [2305.0, 2305.0, 2315.0, 2315.0],
#   [2325.0, 2325.0, 2335.0, 2335.0],
#   [2310.0, 2310.0, 2330.0, 2330.0],
#   [2261.25, 2261.25, 2320.0, 2320.0],
#   [2355.0, 2355.0, 2365.0, 2365.0],
#   [2345.0, 2345.0, 2360.0, 2360.0],
#   [2375.0, 2375.0, 2385.0, 2385.0],
#   [2415.0, 2415.0, 2425.0, 2425.0],
#   [2405.0, 2405.0, 2420.0, 2420.0],
#   [2395.0, 2395.0, 2412.5, 2412.5],
#   [2380.0, 2380.0, 2403.75, 2403.75],
#   [2352.5, 2352.5, 2391.875, 2391.875],
#   [2435.0, 2435.0, 2445.0, 2445.0],
#   [2455.0, 2455.0, 2465.0, 2465.0],
#   [2440.0, 2440.0, 2460.0, 2460.0],
#   [2372.1875, 2372.1875, 2450.0, 2450.0],
#   [2290.625, 2290.625, 2411.09375, 2411.09375],
#   [2144.0625, 2144.0625, 2350.859375, 2350.859375],
#   [1961.25, 1961.25, 2247.4609375, 2247.4609375],
#   [1696.484375, 1696.484375, 2104.35546875, 2104.35546875],
#   [2475.0, 2475.0, 2485.0, 2485.0],
#   [2495.0, 2495.0, 2505.0, 2505.0],
#   [2480.0, 2480.0, 2500.0, 2500.0],
#   [2545.0, 2545.0, 2555.0, 2555.0],
#   [2535.0, 2535.0, 2550.0, 2550.0],
#   [2525.0, 2525.0, 2542.5, 2542.5],
#   [2515.0, 2515.0, 2533.75, 2533.75],
#   [2595.0, 2595.0, 2605.0, 2605.0],
#   [2585.0, 2585.0, 2600.0, 2600.0],
#   [2575.0, 2575.0, 2592.5, 2592.5],
#   [2565.0, 2565.0, 2583.75, 2583.75],
#   [2524.375, 2524.375, 2574.375, 2574.375],
#   [2490.0, 2490.0, 2549.375, 2549.375],
#   [2625.0, 2625.0, 2635.0, 2635.0],
#   [2615.0, 2615.0, 2630.0, 2630.0],
#   [2655.0, 2655.0, 2665.0, 2665.0],
#   [2645.0, 2645.0, 2660.0, 2660.0],
#   [2695.0, 2695.0, 2705.0, 2705.0],
#   [2685.0, 2685.0, 2700.0, 2700.0],
#   [2675.0, 2675.0, 2692.5, 2692.5],
#   [2652.5, 2652.5, 2683.75, 2683.75],
#   [2622.5, 2622.5, 2668.125, 2668.125],
#   [2725.0, 2725.0, 2735.0, 2735.0],
#   [2715.0, 2715.0, 2730.0, 2730.0],
#   [2745.0, 2745.0, 2755.0, 2755.0],
#   [2775.0, 2775.0, 2785.0, 2785.0],
#   [2765.0, 2765.0, 2780.0, 2780.0],
#   [2750.0, 2750.0, 2772.5, 2772.5],
#   [2722.5, 2722.5, 2761.25, 2761.25],
#   [2815.0, 2815.0, 2825.0, 2825.0],
#   [2805.0, 2805.0, 2820.0, 2820.0],
#   [2795.0, 2795.0, 2812.5, 2812.5],
#   [2835.0, 2835.0, 2845.0, 2845.0],
#   [2865.0, 2865.0, 2875.0, 2875.0],
#   [2855.0, 2855.0, 2870.0, 2870.0],
#   [2840.0, 2840.0, 2862.5, 2862.5],
#   [2803.75, 2803.75, 2851.25, 2851.25],
#   [2741.875, 2741.875, 2827.5, 2827.5],
#   [2645.3125, 2645.3125, 2784.6875, 2784.6875],
#   [2519.6875, 2519.6875, 2715.0, 2715.0],
#   [2895.0, 2895.0, 2905.0, 2905.0],
#   [2885.0, 2885.0, 2900.0, 2900.0],
#   [2915.0, 2915.0, 2925.0, 2925.0],
#   [2945.0, 2945.0, 2955.0, 2955.0],
#   [2935.0, 2935.0, 2950.0, 2950.0],
#   [2920.0, 2920.0, 2942.5, 2942.5],
#   [2892.5, 2892.5, 2931.25, 2931.25],
#   [2965.0, 2965.0, 2975.0, 2975.0],
#   [2911.875, 2911.875, 2970.0, 2970.0],
#   [3005.0, 3005.0, 3015.0, 3015.0],
#   [2995.0, 2995.0, 3010.0, 3010.0],
#   [2985.0, 2985.0, 3002.5, 3002.5],
#   [3025.0, 3025.0, 3035.0, 3035.0],
#   [3045.0, 3045.0, 3055.0, 3055.0],
#   [3075.0, 3075.0, 3085.0, 3085.0],
#   [3065.0, 3065.0, 3080.0, 3080.0],
#   [3050.0, 3050.0, 3072.5, 3072.5],
#   [3030.0, 3030.0, 3061.25, 3061.25],
#   [3105.0, 3105.0, 3115.0, 3115.0],
#   [3155.0, 3155.0, 3165.0, 3165.0],
#   [3145.0, 3145.0, 3160.0, 3160.0],
#   [3135.0, 3135.0, 3152.5, 3152.5],
#   [3125.0, 3125.0, 3143.75, 3143.75],
#   [3110.0, 3110.0, 3134.375, 3134.375],
#   [3095.0, 3095.0, 3122.1875, 3122.1875],
#   [3045.625, 3045.625, 3108.59375, 3108.59375],
#   [2993.75, 2993.75, 3077.109375, 3077.109375],
#   [2940.9375, 2940.9375, 3035.4296875, 3035.4296875],
#   [3185.0, 3185.0, 3195.0, 3195.0],
#   [3205.0, 3205.0, 3215.0, 3215.0],
#   [3190.0, 3190.0, 3210.0, 3210.0],
#   [3175.0, 3175.0, 3200.0, 3200.0],
#   [3225.0, 3225.0, 3235.0, 3235.0],
#   [3255.0, 3255.0, 3265.0, 3265.0],
#   [3245.0, 3245.0, 3260.0, 3260.0],
#   [3285.0, 3285.0, 3295.0, 3295.0],
#   [3275.0, 3275.0, 3290.0, 3290.0],
#   [3252.5, 3252.5, 3282.5, 3282.5],
#   [3230.0, 3230.0, 3267.5, 3267.5],
#   [3187.5, 3187.5, 3248.75, 3248.75],
#   [3305.0, 3305.0, 3315.0, 3315.0],
#   [3325.0, 3325.0, 3335.0, 3335.0],
#   [3345.0, 3345.0, 3355.0, 3355.0],
#   [3330.0, 3330.0, 3350.0, 3350.0],
#   [3310.0, 3310.0, 3340.0, 3340.0],
#   [3218.125, 3218.125, 3325.0, 3325.0],
#   [2988.18359375, 2988.18359375, 3271.5625, 3271.5625],
#   [2617.34375, 2617.34375, 3129.873046875, 3129.873046875],
#   [1900.419921875, 1900.419921875, 2873.6083984375, 2873.6083984375],
#   [3365.0, 3365.0, 3375.0, 3375.0],
#   [3395.0, 3395.0, 3405.0, 3405.0],
#   [3385.0, 3385.0, 3400.0, 3400.0],
#   [3425.0, 3425.0, 3435.0, 3435.0],
#   [3465.0, 3465.0, 3475.0, 3475.0],
#   [3455.0, 3455.0, 3470.0, 3470.0],
#   [3445.0, 3445.0, 3462.5, 3462.5],
#   [3495.0, 3495.0, 3505.0, 3505.0],
#   [3485.0, 3485.0, 3500.0, 3500.0],
#   [3453.75, 3453.75, 3492.5, 3492.5],
#   [3430.0, 3430.0, 3473.125, 3473.125],
#   [3415.0, 3415.0, 3451.5625, 3451.5625],
#   [3392.5, 3392.5, 3433.28125, 3433.28125],
#   [3525.0, 3525.0, 3535.0, 3535.0],
#   [3515.0, 3515.0, 3530.0, 3530.0],
#   [3555.0, 3555.0, 3565.0, 3565.0],
#   [3545.0, 3545.0, 3560.0, 3560.0],
#   [3522.5, 3522.5, 3552.5, 3552.5],
#   [3585.0, 3585.0, 3595.0, 3595.0],
#   [3575.0, 3575.0, 3590.0, 3590.0],
#   [3615.0, 3615.0, 3625.0, 3625.0],
#   [3605.0, 3605.0, 3620.0, 3620.0],
#   [3635.0, 3635.0, 3645.0, 3645.0],
#   [3655.0, 3655.0, 3665.0, 3665.0],
#   [3685.0, 3685.0, 3695.0, 3695.0],
#   [3675.0, 3675.0, 3690.0, 3690.0],
#   [3660.0, 3660.0, 3682.5, 3682.5],
#   [3640.0, 3640.0, 3671.25, 3671.25],
#   [3715.0, 3715.0, 3725.0, 3725.0],
#   [3705.0, 3705.0, 3720.0, 3720.0],
#   [3735.0, 3735.0, 3745.0, 3745.0],
#   [3712.5, 3712.5, 3740.0, 3740.0],
#   [3655.625, 3655.625, 3726.25, 3726.25],
#   [3612.5, 3612.5, 3690.9375, 3690.9375],
#   [3755.0, 3755.0, 3765.0, 3765.0],
#   [3775.0, 3775.0, 3785.0, 3785.0],
#   [3795.0, 3795.0, 3805.0, 3805.0],
#   [3780.0, 3780.0, 3800.0, 3800.0],
#   [3760.0, 3760.0, 3790.0, 3790.0],
#   [3651.71875, 3651.71875, 3775.0, 3775.0],
#   [3582.5, 3582.5, 3713.359375, 3713.359375],
#   [3537.5, 3537.5, 3647.9296875, 3647.9296875],
#   [3825.0, 3825.0, 3835.0, 3835.0],
#   [3815.0, 3815.0, 3830.0, 3830.0],
#   [3845.0, 3845.0, 3855.0, 3855.0],
#   [3875.0, 3875.0, 3885.0, 3885.0],
#   [3895.0, 3895.0, 3905.0, 3905.0],
#   [3880.0, 3880.0, 3900.0, 3900.0],
#   [3865.0, 3865.0, 3890.0, 3890.0],
#   [3850.0, 3850.0, 3877.5, 3877.5],
#   [3822.5, 3822.5, 3863.75, 3863.75],
#   [3925.0, 3925.0, 3935.0, 3935.0],
#   [3915.0, 3915.0, 3930.0, 3930.0],
#   [3955.0, 3955.0, 3965.0, 3965.0],
#   [3945.0, 3945.0, 3960.0, 3960.0],
#   [3985.0, 3985.0, 3995.0, 3995.0],
#   [3975.0, 3975.0, 3990.0, 3990.0],
#   [3952.5, 3952.5, 3982.5, 3982.5],
#   [4005.0, 4005.0, 4015.0, 4015.0],
#   [4045.0, 4045.0, 4055.0, 4055.0],
#   [4035.0, 4035.0, 4050.0, 4050.0],
#   [4025.0, 4025.0, 4042.5, 4042.5],
#   [4010.0, 4010.0, 4033.75, 4033.75],
#   [3967.5, 3967.5, 4021.875, 4021.875],
#   [3922.5, 3922.5, 3994.6875, 3994.6875],
#   [3843.125, 3843.125, 3958.59375, 3958.59375],
#   [4065.0, 4065.0, 4075.0, 4075.0],
#   [4095.0, 4095.0, 4105.0, 4105.0],
#   [4085.0, 4085.0, 4100.0, 4100.0],
#   [4070.0, 4070.0, 4092.5, 4092.5],
#   [4115.0, 4115.0, 4125.0, 4125.0],
#   [4145.0, 4145.0, 4155.0, 4155.0],
#   [4135.0, 4135.0, 4150.0, 4150.0],
#   [4120.0, 4120.0, 4142.5, 4142.5],
#   [4081.25, 4081.25, 4131.25, 4131.25],
#   [4165.0, 4165.0, 4175.0, 4175.0],
#   [4195.0, 4195.0, 4205.0, 4205.0],
#   [4185.0, 4185.0, 4200.0, 4200.0],
#   [4170.0, 4170.0, 4192.5, 4192.5],
#   [4225.0, 4225.0, 4235.0, 4235.0],
#   [4215.0, 4215.0, 4230.0, 4230.0],
#   [4255.0, 4255.0, 4265.0, 4265.0],
#   [4245.0, 4245.0, 4260.0, 4260.0],
#   [4275.0, 4275.0, 4285.0, 4285.0],
#   [4305.0, 4305.0, 4315.0, 4315.0],
#   [4295.0, 4295.0, 4310.0, 4310.0],
#   [4280.0, 4280.0, 4302.5, 4302.5],
#   [4252.5, 4252.5, 4291.25, 4291.25],
#   [4222.5, 4222.5, 4271.875, 4271.875],
#   [4181.25, 4181.25, 4247.1875, 4247.1875],
#   [4325.0, 4325.0, 4335.0, 4335.0],
#   [4345.0, 4345.0, 4355.0, 4355.0],
#   [4330.0, 4330.0, 4350.0, 4350.0],
#   [4365.0, 4365.0, 4375.0, 4375.0],
#   [4385.0, 4385.0, 4395.0, 4395.0],
#   [4370.0, 4370.0, 4390.0, 4390.0],
#   [4340.0, 4340.0, 4380.0, 4380.0],
#   [4214.21875, 4214.21875, 4360.0, 4360.0],
#   [4106.25, 4106.25, 4287.109375, 4287.109375],
#   [3900.859375, 3900.859375, 4196.6796875, 4196.6796875],
#   [3592.71484375, 3592.71484375, 4048.76953125, 4048.76953125],
#   [3412.890625, 3412.890625, 3820.7421875, 3820.7421875],
#   [3370.0, 3370.0, 3616.81640625, 3616.81640625],
#   [2387.01416015625, 2387.01416015625, 3493.408203125, 3493.408203125],
#   [571.81884765625, 571.81884765625, 2940.211181640625, 2940.211181640625],
#   [20.625, 20.625, 1756.0150146484375, 1756.0150146484375]],
#  'dcoord': [[0.0, 2.9881043412799277, 2.9881043412799277, 0.0],
#   [0.0, 5.912132724230831, 5.912132724230831, 2.9881043412799277],
#   [0.0, 6.289802068548619, 6.289802068548619, 0.0],
#   [5.912132724230831,
#    10.002072830774546,
#    10.002072830774546,
#    6.289802068548619],
#   [0.0, 24.67940341058281, 24.67940341058281, 10.002072830774546],
#   [0.0, 0.9392904614476787, 0.9392904614476787, 0.0],
#   [0.0, 0.5920531393271186, 0.5920531393271186, 0.0],
#   [0.0, 0.700654814813363, 0.700654814813363, 0.5920531393271186],
#   [0.0, 0.25646131254803683, 0.25646131254803683, 0.0],
#   [0.0, 0.3989640274194644, 0.3989640274194644, 0.0],
#   [0.25646131254803683,
#    1.0223159988446742,
#    1.0223159988446742,
#    0.3989640274194644],
#   [0.700654814813363,
#    1.6352007802416775,
#    1.6352007802416775,
#    1.0223159988446742],
#   [0.9392904614476787,
#    2.522158949390465,
#    2.522158949390465,
#    1.6352007802416775],
#   [0.0, 0.626576068470668, 0.626576068470668, 0.0],
#   [0.0, 1.1472421446007701, 1.1472421446007701, 0.626576068470668],
#   [0.0, 0.595148867598951, 0.595148867598951, 0.0],
#   [0.0, 1.1052334747430388, 1.1052334747430388, 0.595148867598951],
#   [0.0, 1.4267461426299124, 1.4267461426299124, 1.1052334747430388],
#   [1.1472421446007701,
#    1.593895970952753,
#    1.593895970952753,
#    1.4267461426299124],
#   [0.0, 2.688545787698034, 2.688545787698034, 1.593895970952753],
#   [2.522158949390465, 4.064614492317031, 4.064614492317031, 2.688545787698034],
#   [0.0, 0.9805212407881027, 0.9805212407881027, 0.0],
#   [0.0, 1.4054415835022314, 1.4054415835022314, 0.9805212407881027],
#   [0.0, 2.9095569554269534, 2.9095569554269534, 1.4054415835022314],
#   [0.0, 0.5990790927727321, 0.5990790927727321, 0.0],
#   [0.0, 1.0997310897892825, 1.0997310897892825, 0.5990790927727321],
#   [0.0, 1.7117267744454143, 1.7117267744454143, 0.0],
#   [1.0997310897892825,
#    3.3170618821818625,
#    3.3170618821818625,
#    1.7117267744454143],
#   [2.9095569554269534,
#    5.461892369185779,
#    5.461892369185779,
#    3.3170618821818625],
#   [4.064614492317031, 7.323875537925583, 7.323875537925583, 5.461892369185779],
#   [0.0, 0.44130164387563, 0.44130164387563, 0.0],
#   [0.0, 0.31133106366414764, 0.31133106366414764, 0.0],
#   [0.0, 0.5839459717015383, 0.5839459717015383, 0.31133106366414764],
#   [0.44130164387563,
#    0.8810476136863054,
#    0.8810476136863054,
#    0.5839459717015383],
#   [0.0, 1.0230765395496693, 1.0230765395496693, 0.8810476136863054],
#   [0.0, 0.2855656243132561, 0.2855656243132561, 0.0],
#   [0.0, 0.5592336646383752, 0.5592336646383752, 0.2855656243132561],
#   [0.0, 0.2513503790924347, 0.2513503790924347, 0.0],
#   [0.0, 0.46994663254198765, 0.46994663254198765, 0.2513503790924347],
#   [0.0, 0.5745739473957784, 0.5745739473957784, 0.0],
#   [0.46994663254198765,
#    0.9877610198171372,
#    0.9877610198171372,
#    0.5745739473957784],
#   [0.5592336646383752,
#    1.1243609076634542,
#    1.1243609076634542,
#    0.9877610198171372],
#   [0.0, 1.4785123310649626, 1.4785123310649626, 1.1243609076634542],
#   [1.0230765395496693,
#    2.1031981822991006,
#    2.1031981822991006,
#    1.4785123310649626],
#   [0.0, 0.5073467904209303, 0.5073467904209303, 0.0],
#   [0.0, 0.26315296174800995, 0.26315296174800995, 0.0],
#   [0.0, 0.3241575719092391, 0.3241575719092391, 0.26315296174800995],
#   [0.0, 0.39926438911045403, 0.39926438911045403, 0.0],
#   [0.3241575719092391,
#    0.7074499860268881,
#    0.7074499860268881,
#    0.39926438911045403],
#   [0.0, 1.2599490900688213, 1.2599490900688213, 0.7074499860268881],
#   [0.0, 0.5181697107988652, 0.5181697107988652, 0.0],
#   [0.0, 0.5564653367892333, 0.5564653367892333, 0.0],
#   [0.0, 0.369178214216239, 0.369178214216239, 0.0],
#   [0.0, 0.28524503687173036, 0.28524503687173036, 0.0],
#   [0.0, 0.3942641444166443, 0.3942641444166443, 0.0],
#   [0.0, 0.5051055044259123, 0.5051055044259123, 0.3942641444166443],
#   [0.28524503687173036,
#    0.6024055096276455,
#    0.6024055096276455,
#    0.5051055044259123],
#   [0.369178214216239,
#    0.9239274133790671,
#    0.9239274133790671,
#    0.6024055096276455],
#   [0.5564653367892333,
#    1.2704447032627664,
#    1.2704447032627664,
#    0.9239274133790671],
#   [0.5181697107988652,
#    1.3115935920290125,
#    1.3115935920290125,
#    1.2704447032627664],
#   [1.2599490900688213,
#    1.9890783431113561,
#    1.9890783431113561,
#    1.3115935920290125],
#   [0.5073467904209303,
#    2.124979719909349,
#    2.124979719909349,
#    1.9890783431113561],
#   [2.1031981822991006,
#    2.8998344514107925,
#    2.8998344514107925,
#    2.124979719909349],
#   [0.0, 0.682472306491131, 0.682472306491131, 0.0],
#   [0.0, 0.5665993270117509, 0.5665993270117509, 0.0],
#   [0.0, 0.6473124968462903, 0.6473124968462903, 0.0],
#   [0.5665993270117509,
#    0.9677912246168029,
#    0.9677912246168029,
#    0.6473124968462903],
#   [0.682472306491131,
#    1.0425009286476088,
#    1.0425009286476088,
#    0.9677912246168029],
#   [0.0, 0.3341525618605689, 0.3341525618605689, 0.0],
#   [0.0, 0.9820514697318378, 0.9820514697318378, 0.3341525618605689],
#   [0.0, 1.1371827232886411, 1.1371827232886411, 0.9820514697318378],
#   [1.0425009286476088,
#    1.4604485407174206,
#    1.4604485407174206,
#    1.1371827232886411],
#   [0.0, 0.8636378977093453, 0.8636378977093453, 0.0],
#   [0.0, 0.545538833207658, 0.545538833207658, 0.0],
#   [0.0, 0.3568662506299086, 0.3568662506299086, 0.0],
#   [0.0, 0.4023591742515353, 0.4023591742515353, 0.0],
#   [0.0, 0.7794679749480349, 0.7794679749480349, 0.4023591742515353],
#   [0.3568662506299086,
#    0.8801678647231636,
#    0.8801678647231636,
#    0.7794679749480349],
#   [0.545538833207658,
#    1.5844173156660384,
#    1.5844173156660384,
#    0.8801678647231636],
#   [0.8636378977093453,
#    1.8756315282292608,
#    1.8756315282292608,
#    1.5844173156660384],
#   [0.0, 2.7351554632211466, 2.7351554632211466, 1.8756315282292608],
#   [1.4604485407174206,
#    3.424120153517595,
#    3.424120153517595,
#    2.7351554632211466],
#   [2.8998344514107925,
#    4.658625829944109,
#    4.658625829944109,
#    3.424120153517595],
#   [0.0, 0.2467882549103546, 0.2467882549103546, 0.0],
#   [0.0, 0.4143152951134902, 0.4143152951134902, 0.0],
#   [0.2467882549103546,
#    0.4747179156186994,
#    0.4747179156186994,
#    0.4143152951134902],
#   [0.0, 0.5224446552977196, 0.5224446552977196, 0.0],
#   [0.0, 0.3907530534690649, 0.3907530534690649, 0.0],
#   [0.0, 0.34271218106484175, 0.34271218106484175, 0.0],
#   [0.0, 0.5114526459265543, 0.5114526459265543, 0.34271218106484175],
#   [0.3907530534690649,
#    0.7504856770353011,
#    0.7504856770353011,
#    0.5114526459265543],
#   [0.5224446552977196,
#    1.0827301956930675,
#    1.0827301956930675,
#    0.7504856770353011],
#   [0.4747179156186994,
#    1.2334857012602238,
#    1.2334857012602238,
#    1.0827301956930675],
#   [0.0, 0.39751095323170904, 0.39751095323170904, 0.0],
#   [0.0, 0.5039669775047886, 0.5039669775047886, 0.39751095323170904],
#   [0.0, 0.9154214941002942, 0.9154214941002942, 0.5039669775047886],
#   [0.0, 0.3705187707476224, 0.3705187707476224, 0.0],
#   [0.0, 0.3221714725204729, 0.3221714725204729, 0.0],
#   [0.0, 0.6467080826249992, 0.6467080826249992, 0.3221714725204729],
#   [0.3705187707476224,
#    1.0323908498904801,
#    1.0323908498904801,
#    0.6467080826249992],
#   [0.9154214941002942,
#    1.698482851331634,
#    1.698482851331634,
#    1.0323908498904801],
#   [1.2334857012602238,
#    2.3200890260715545,
#    2.3200890260715545,
#    1.698482851331634],
#   [0.0, 0.4524995613942573, 0.4524995613942573, 0.0],
#   [0.0, 0.6778935899627455, 0.6778935899627455, 0.4524995613942573],
#   [0.0, 0.45814045636198875, 0.45814045636198875, 0.0],
#   [0.0, 0.5952015428407339, 0.5952015428407339, 0.45814045636198875],
#   [0.0, 0.7401884313116464, 0.7401884313116464, 0.5952015428407339],
#   [0.6778935899627455,
#    1.0863676684773935,
#    1.0863676684773935,
#    0.7401884313116464],
#   [0.0, 0.11384440463857788, 0.11384440463857788, 0.0],
#   [0.0, 0.24435343183616517, 0.24435343183616517, 0.11384440463857788],
#   [0.0, 0.4452630889688223, 0.4452630889688223, 0.0],
#   [0.24435343183616517,
#    0.7896609927756191,
#    0.7896609927756191,
#    0.4452630889688223],
#   [0.0, 0.37465431903723506, 0.37465431903723506, 0.0],
#   [0.0, 0.33190326526194214, 0.33190326526194214, 0.0],
#   [0.0, 0.6313589279015674, 0.6313589279015674, 0.33190326526194214],
#   [0.37465431903723506,
#    0.7007875772378911,
#    0.7007875772378911,
#    0.6313589279015674],
#   [0.0, 0.5538124648893785, 0.5538124648893785, 0.0],
#   [0.0, 0.672518496885939, 0.672518496885939, 0.5538124648893785],
#   [0.0, 0.419328224919947, 0.419328224919947, 0.0],
#   [0.0, 0.5073921866941326, 0.5073921866941326, 0.419328224919947],
#   [0.0, 0.15678346479159946, 0.15678346479159946, 0.0],
#   [0.0, 0.3056839420196135, 0.3056839420196135, 0.0],
#   [0.15678346479159946,
#    0.5136445417699202,
#    0.5136445417699202,
#    0.3056839420196135],
#   [0.5073921866941326,
#    0.852884952002588,
#    0.852884952002588,
#    0.5136445417699202],
#   [0.672518496885939,
#    1.1616864998768586,
#    1.1616864998768586,
#    0.852884952002588],
#   [0.7007875772378911,
#    1.4939087746073856,
#    1.4939087746073856,
#    1.1616864998768586],
#   [0.7896609927756191,
#    1.7207265671406538,
#    1.7207265671406538,
#    1.4939087746073856],
#   [0.0, 0.7099246573635257, 0.7099246573635257, 0.0],
#   [0.0, 0.8540828643539751, 0.8540828643539751, 0.7099246573635257],
#   [0.0, 0.34363739006378013, 0.34363739006378013, 0.0],
#   [0.0, 0.45234374813531103, 0.45234374813531103, 0.34363739006378013],
#   [0.0, 0.7201268721096853, 0.7201268721096853, 0.45234374813531103],
#   [0.0, 0.2875909524909293, 0.2875909524909293, 0.0],
#   [0.0, 0.30537987208157635, 0.30537987208157635, 0.0],
#   [0.0, 0.44812588103628165, 0.44812588103628165, 0.0],
#   [0.30537987208157635,
#    0.48671887495174565,
#    0.48671887495174565,
#    0.44812588103628165],
#   [0.2875909524909293,
#    1.0951479186252666,
#    1.0951479186252666,
#    0.48671887495174565],
#   [0.7201268721096853,
#    1.2141182182175443,
#    1.2141182182175443,
#    1.0951479186252666],
#   [0.0, 1.5519500880555297, 1.5519500880555297, 1.2141182182175443],
#   [0.8540828643539751,
#    2.2205345314444007,
#    2.2205345314444007,
#    1.5519500880555297],
#   [1.7207265671406538,
#    2.5858608147850357,
#    2.5858608147850357,
#    2.2205345314444007],
#   [1.0863676684773935,
#    2.7394576279294642,
#    2.7394576279294642,
#    2.5858608147850357],
#   [2.3200890260715545,
#    4.1684231664008005,
#    4.1684231664008005,
#    2.7394576279294642],
#   [0.0, 0.9561269109532428, 0.9561269109532428, 0.0],
#   [0.0, 1.5247328745751303, 1.5247328745751303, 0.0],
#   [0.9561269109532428,
#    1.996837563214041,
#    1.996837563214041,
#    1.5247328745751303],
#   [0.0, 1.1915130185337897, 1.1915130185337897, 0.0],
#   [0.0, 0.3174860263420715, 0.3174860263420715, 0.0],
#   [0.0, 0.49971339762419204, 0.49971339762419204, 0.3174860263420715],
#   [0.0, 0.8987462005519969, 0.8987462005519969, 0.49971339762419204],
#   [0.0, 1.1442450199287666, 1.1442450199287666, 0.0],
#   [0.8987462005519969,
#    2.450430138629523,
#    2.450430138629523,
#    1.1442450199287666],
#   [1.1915130185337897,
#    3.252687110319136,
#    3.252687110319136,
#    2.450430138629523],
#   [1.996837563214041, 4.957060756605897, 4.957060756605897, 3.252687110319136],
#   [4.1684231664008005,
#    7.811019996178596,
#    7.811019996178596,
#    4.957060756605897],
#   [4.658625829944109, 9.670140947233955, 9.670140947233955, 7.811019996178596],
#   [7.323875537925583,
#    18.063393981628494,
#    18.063393981628494,
#    9.670140947233955],
#   [0.0, 0.43514338287633475, 0.43514338287633475, 0.0],
#   [0.0, 0.30388049311350684, 0.30388049311350684, 0.0],
#   [0.0, 0.39359558037485204, 0.39359558037485204, 0.30388049311350684],
#   [0.0, 0.5094232807649032, 0.5094232807649032, 0.39359558037485204],
#   [0.43514338287633475,
#    0.7837512888908068,
#    0.7837512888908068,
#    0.5094232807649032],
#   [0.0, 0.09708669241433066, 0.09708669241433066, 0.0],
#   [0.0, 0.09573517003051535, 0.09573517003051535, 0.0],
#   [0.0, 0.11366248930128717, 0.11366248930128717, 0.09573517003051535],
#   [0.09708669241433066,
#    0.21025490568157937,
#    0.21025490568157937,
#    0.11366248930128717],
#   [0.0, 0.09060009899760772, 0.09060009899760772, 0.0],
#   [0.0, 0.24438830314981233, 0.24438830314981233, 0.09060009899760772],
#   [0.0, 0.1520804307967975, 0.1520804307967975, 0.0],
#   [0.0, 0.21699018949993537, 0.21699018949993537, 0.1520804307967975],
#   [0.0, 0.05323768533081131, 0.05323768533081131, 0.0],
#   [0.0, 0.21931695796762715, 0.21931695796762715, 0.0],
#   [0.05323768533081131,
#    0.26090859256875304,
#    0.26090859256875304,
#    0.21931695796762715],
#   [0.21699018949993537,
#    0.35985172155379935,
#    0.35985172155379935,
#    0.26090859256875304],
#   [0.24438830314981233,
#    0.39678514349681593,
#    0.39678514349681593,
#    0.35985172155379935],
#   [0.21025490568157937,
#    0.5840906248283784,
#    0.5840906248283784,
#    0.39678514349681593],
#   [0.0, 0.15230804004957624, 0.15230804004957624, 0.0],
#   [0.0, 0.21109271123062215, 0.21109271123062215, 0.15230804004957624],
#   [0.0, 0.2976876467207054, 0.2976876467207054, 0.0],
#   [0.21109271123062215,
#    0.4277552832818563,
#    0.4277552832818563,
#    0.2976876467207054],
#   [0.0, 0.07562687538745427, 0.07562687538745427, 0.0],
#   [0.0, 0.21074545860209487, 0.21074545860209487, 0.0],
#   [0.07562687538745427,
#    0.2998329049169054,
#    0.2998329049169054,
#    0.21074545860209487],
#   [0.0, 0.2147827972539942, 0.2147827972539942, 0.0],
#   [0.0, 0.24738282925318408, 0.24738282925318408, 0.0],
#   [0.2147827972539942,
#    0.3112417026023482,
#    0.3112417026023482,
#    0.24738282925318408],
#   [0.2998329049169054,
#    0.5259993374035369,
#    0.5259993374035369,
#    0.3112417026023482],
#   [0.4277552832818563,
#    0.7904268006605776,
#    0.7904268006605776,
#    0.5259993374035369],
#   [0.5840906248283784,
#    0.9665056731559539,
#    0.9665056731559539,
#    0.7904268006605776],
#   [0.7837512888908068,
#    1.8360933312042402,
#    1.8360933312042402,
#    0.9665056731559539],
#   [0.0, 0.044381852867995675, 0.044381852867995675, 0.0],
#   [0.0, 0.1846441949554032, 0.1846441949554032, 0.0],
#   [0.044381852867995675,
#    0.2236562126605631,
#    0.2236562126605631,
#    0.1846441949554032],
#   [0.0, 0.27651221173915386, 0.27651221173915386, 0.2236562126605631],
#   [0.0, 0.0596788637020658, 0.0596788637020658, 0.0],
#   [0.0, 0.14778947327092898, 0.14778947327092898, 0.0],
#   [0.0596788637020658,
#    0.1639200614598077,
#    0.1639200614598077,
#    0.14778947327092898],
#   [0.0, 0.24901022792363867, 0.24901022792363867, 0.1639200614598077],
#   [0.0, 0.15148845304757835, 0.15148845304757835, 0.0],
#   [0.0, 0.2497576192265755, 0.2497576192265755, 0.15148845304757835],
#   [0.24901022792363867,
#    0.3823665588855632,
#    0.3823665588855632,
#    0.2497576192265755],
#   [0.0, 0.41234053747488986, 0.41234053747488986, 0.3823665588855632],
#   [0.27651221173915386,
#    0.6055616535290683,
#    0.6055616535290683,
#    0.41234053747488986],
#   [0.0, 1.3199588426075435, 1.3199588426075435, 0.6055616535290683],
#   [0.0, 0.19885224939909352, 0.19885224939909352, 0.0],
#   [0.0, 0.32750875954156966, 0.32750875954156966, 0.19885224939909352],
#   [0.0, 0.29301358893161916, 0.29301358893161916, 0.0],
#   [0.0, 0.3881674479713845, 0.3881674479713845, 0.29301358893161916],
#   [0.32750875954156966,
#    0.6381914368853161,
#    0.6381914368853161,
#    0.3881674479713845],
#   [0.0, 0.28119292184086503, 0.28119292184086503, 0.0],
#   [0.0, 0.3363063910433366, 0.3363063910433366, 0.0],
#   [0.28119292184086503,
#    0.5975290767614269,
#    0.5975290767614269,
#    0.3363063910433366],
#   [0.0, 0.352553946102833, 0.352553946102833, 0.0],
#   [0.0, 0.2410148437904703, 0.2410148437904703, 0.0],
#   [0.0, 0.40601067960066006, 0.40601067960066006, 0.2410148437904703],
#   [0.352553946102833,
#    0.6088398572429822,
#    0.6088398572429822,
#    0.40601067960066006],
#   [0.5975290767614269,
#    0.7533871914657625,
#    0.7533871914657625,
#    0.6088398572429822],
#   [0.6381914368853161,
#    1.2582734765545147,
#    1.2582734765545147,
#    0.7533871914657625],
#   [0.0, 0.13861661775121537, 0.13861661775121537, 0.0],
#   [0.0, 0.20885323408572057, 0.20885323408572057, 0.13861661775121537],
#   [0.0, 0.16092860708708845, 0.16092860708708845, 0.0],
#   [0.0, 0.17322548817057273, 0.17322548817057273, 0.0],
#   [0.16092860708708845,
#    0.32366808819285886,
#    0.32366808819285886,
#    0.17322548817057273],
#   [0.20885323408572057,
#    0.40602112456994865,
#    0.40602112456994865,
#    0.32366808819285886],
#   [0.0, 0.1824026015466827, 0.1824026015466827, 0.0],
#   [0.0, 0.2897195157623116, 0.2897195157623116, 0.0],
#   [0.1824026015466827,
#    0.4881009478517171,
#    0.4881009478517171,
#    0.2897195157623116],
#   [0.40602112456994865,
#    0.827120763760277,
#    0.827120763760277,
#    0.4881009478517171],
#   [0.0, 0.22604421937078067, 0.22604421937078067, 0.0],
#   [0.0, 0.3192967272082686, 0.3192967272082686, 0.22604421937078067],
#   [0.0, 0.1652571622093178, 0.1652571622093178, 0.0],
#   [0.0, 0.16095333580385907, 0.16095333580385907, 0.0],
#   [0.0, 0.26167261374257444, 0.26167261374257444, 0.16095333580385907],
#   [0.0, 0.32794626563511975, 0.32794626563511975, 0.26167261374257444],
#   [0.1652571622093178,
#    0.39993992866363187,
#    0.39993992866363187,
#    0.32794626563511975],
#   [0.3192967272082686,
#    0.4844568086483612,
#    0.4844568086483612,
#    0.39993992866363187],
#   [0.0, 0.27645238742490946, 0.27645238742490946, 0.0],
#   [0.0, 0.3821618405273214, 0.3821618405273214, 0.0],
#   [0.27645238742490946,
#    0.5687775164514882,
#    0.5687775164514882,
#    0.3821618405273214],
#   [0.4844568086483612,
#    1.0069086794089799,
#    1.0069086794089799,
#    0.5687775164514882],
#   [0.827120763760277,
#    1.4214117733710143,
#    1.4214117733710143,
#    1.0069086794089799],
#   [1.2582734765545147,
#    1.5655852992053076,
#    1.5655852992053076,
#    1.4214117733710143],
#   [1.3199588426075435,
#    2.135873017834241,
#    2.135873017834241,
#    1.5655852992053076],
#   [1.8360933312042402,
#    2.985192854740199,
#    2.985192854740199,
#    2.135873017834241],
#   [0.0, 0.34322593533651113, 0.34322593533651113, 0.0],
#   [0.0, 0.41697096072665585, 0.41697096072665585, 0.0],
#   [0.34322593533651113,
#    0.5899763280593643,
#    0.5899763280593643,
#    0.41697096072665585],
#   [0.0, 0.15504455461345185, 0.15504455461345185, 0.0],
#   [0.0, 0.23150736495146865, 0.23150736495146865, 0.15504455461345185],
#   [0.0, 0.27183453320014805, 0.27183453320014805, 0.23150736495146865],
#   [0.0, 0.39422092012206716, 0.39422092012206716, 0.27183453320014805],
#   [0.0, 0.1315081274725326, 0.1315081274725326, 0.0],
#   [0.0, 0.2319697279609778, 0.2319697279609778, 0.1315081274725326],
#   [0.0, 0.32097330509851535, 0.32097330509851535, 0.2319697279609778],
#   [0.0, 0.4931905536620071, 0.4931905536620071, 0.32097330509851535],
#   [0.39422092012206716,
#    0.880967323651737,
#    0.880967323651737,
#    0.4931905536620071],
#   [0.5899763280593643,
#    1.0895289700697697,
#    1.0895289700697697,
#    0.880967323651737],
#   [0.0, 0.23719117206443538, 0.23719117206443538, 0.0],
#   [0.0, 0.3722306269567357, 0.3722306269567357, 0.23719117206443538],
#   [0.0, 0.1836850380977762, 0.1836850380977762, 0.0],
#   [0.0, 0.3281365579642656, 0.3281365579642656, 0.1836850380977762],
#   [0.0, 0.06628148105701794, 0.06628148105701794, 0.0],
#   [0.0, 0.19300347988287786, 0.19300347988287786, 0.06628148105701794],
#   [0.0, 0.4158873487853804, 0.4158873487853804, 0.19300347988287786],
#   [0.3281365579642656,
#    0.6166481021771691,
#    0.6166481021771691,
#    0.4158873487853804],
#   [0.3722306269567357,
#    0.8410248468125725,
#    0.8410248468125725,
#    0.6166481021771691],
#   [0.0, 0.24064717127988325, 0.24064717127988325, 0.0],
#   [0.0, 0.3461015879796948, 0.3461015879796948, 0.24064717127988325],
#   [0.0, 0.17237405254814456, 0.17237405254814456, 0.0],
#   [0.0, 0.17770255538938579, 0.17770255538938579, 0.0],
#   [0.0, 0.3659407942825621, 0.3659407942825621, 0.17770255538938579],
#   [0.17237405254814456,
#    0.45307547247926094,
#    0.45307547247926094,
#    0.3659407942825621],
#   [0.3461015879796948,
#    0.5200357000040663,
#    0.5200357000040663,
#    0.45307547247926094],
#   [0.0, 0.13419436701913287, 0.13419436701913287, 0.0],
#   [0.0, 0.2409075154316289, 0.2409075154316289, 0.13419436701913287],
#   [0.0, 0.3404663763237325, 0.3404663763237325, 0.2409075154316289],
#   [0.0, 0.2372345125918405, 0.2372345125918405, 0.0],
#   [0.0, 0.1427628281026006, 0.1427628281026006, 0.0],
#   [0.0, 0.2481684832233888, 0.2481684832233888, 0.1427628281026006],
#   [0.2372345125918405,
#    0.356625881199953,
#    0.356625881199953,
#    0.2481684832233888],
#   [0.3404663763237325,
#    0.6851399239000663,
#    0.6851399239000663,
#    0.356625881199953],
#   [0.5200357000040663,
#    0.9895060730781884,
#    0.9895060730781884,
#    0.6851399239000663],
#   [0.8410248468125725,
#    1.2737515726512125,
#    1.2737515726512125,
#    0.9895060730781884],
#   [1.0895289700697697,
#    2.4495519757498356,
#    2.4495519757498356,
#    1.2737515726512125],
#   [0.0, 0.3301109204944086, 0.3301109204944086, 0.0],
#   [0.0, 0.4111751442404822, 0.4111751442404822, 0.3301109204944086],
#   [0.0, 0.3555228936443311, 0.3555228936443311, 0.0],
#   [0.0, 0.2845137325637866, 0.2845137325637866, 0.0],
#   [0.0, 0.4741496060695163, 0.4741496060695163, 0.2845137325637866],
#   [0.3555228936443311,
#    0.6159232140467531,
#    0.6159232140467531,
#    0.4741496060695163],
#   [0.4111751442404822,
#    0.7065936691491361,
#    0.7065936691491361,
#    0.6159232140467531],
#   [0.0, 0.7755756907725719, 0.7755756907725719, 0.0],
#   [0.7065936691491361,
#    1.0064177938194354,
#    1.0064177938194354,
#    0.7755756907725719],
#   [0.0, 0.18617943302562556, 0.18617943302562556, 0.0],
#   [0.0, 0.3563636138102475, 0.3563636138102475, 0.18617943302562556],
#   [0.0, 0.5497224104253936, 0.5497224104253936, 0.3563636138102475],
#   [0.0, 0.2828313562109842, 0.2828313562109842, 0.0],
#   [0.0, 0.19496721465478598, 0.19496721465478598, 0.0],
#   [0.0, 0.15707716603990132, 0.15707716603990132, 0.0],
#   [0.0, 0.25851732916904097, 0.25851732916904097, 0.15707716603990132],
#   [0.19496721465478598,
#    0.3110158557018252,
#    0.3110158557018252,
#    0.25851732916904097],
#   [0.2828313562109842,
#    0.4599371879224238,
#    0.4599371879224238,
#    0.3110158557018252],
#   [0.0, 0.20433506863447734, 0.20433506863447734, 0.0],
#   [0.0, 0.12765414246797122, 0.12765414246797122, 0.0],
#   [0.0, 0.21070492825012083, 0.21070492825012083, 0.12765414246797122],
#   [0.0, 0.27849555952384764, 0.27849555952384764, 0.21070492825012083],
#   [0.0, 0.30189749411615374, 0.30189749411615374, 0.27849555952384764],
#   [0.20433506863447734,
#    0.4904895508244757,
#    0.4904895508244757,
#    0.30189749411615374],
#   [0.0, 0.6908093060181033, 0.6908093060181033, 0.4904895508244757],
#   [0.4599371879224238,
#    1.0995145106177882,
#    1.0995145106177882,
#    0.6908093060181033],
#   [0.5497224104253936,
#    1.374901607770948,
#    1.374901607770948,
#    1.0995145106177882],
#   [1.0064177938194354,
#    1.7754194990948589,
#    1.7754194990948589,
#    1.374901607770948],
#   [0.0, 0.273027757397817, 0.273027757397817, 0.0],
#   [0.0, 0.3264880497880759, 0.3264880497880759, 0.0],
#   [0.273027757397817,
#    0.535395854524556,
#    0.535395854524556,
#    0.3264880497880759],
#   [0.0, 0.6388099505731019, 0.6388099505731019, 0.535395854524556],
#   [0.0, 0.3219336771807018, 0.3219336771807018, 0.0],
#   [0.0, 0.2618621783300695, 0.2618621783300695, 0.0],
#   [0.0, 0.35027082999728715, 0.35027082999728715, 0.2618621783300695],
#   [0.0, 0.26088617252019614, 0.26088617252019614, 0.0],
#   [0.0, 0.37899424688536265, 0.37899424688536265, 0.26088617252019614],
#   [0.35027082999728715,
#    0.6168152152574531,
#    0.6168152152574531,
#    0.37899424688536265],
#   [0.3219336771807018,
#    0.8361339939016695,
#    0.8361339939016695,
#    0.6168152152574531],
#   [0.6388099505731019,
#    1.1969201896015726,
#    1.1969201896015726,
#    0.8361339939016695],
#   [0.0, 0.5784891707075827, 0.5784891707075827, 0.0],
#   [0.0, 0.5293635904306594, 0.5293635904306594, 0.0],
#   [0.0, 0.6818050913147238, 0.6818050913147238, 0.0],
#   [0.5293635904306594,
#    0.8988034306034747,
#    0.8988034306034747,
#    0.6818050913147238],
#   [0.5784891707075827,
#    1.5711295277605921,
#    1.5711295277605921,
#    0.8988034306034747],
#   [1.1969201896015726,
#    2.0417457303346964,
#    2.0417457303346964,
#    1.5711295277605921],
#   [1.7754194990948589,
#    3.3450726414179726,
#    3.3450726414179726,
#    2.0417457303346964],
#   [2.4495519757498356,
#    6.2177797693892485,
#    6.2177797693892485,
#    3.3450726414179726],
#   [2.985192854740199,
#    7.2562756344701596,
#    7.2562756344701596,
#    6.2177797693892485],
#   [0.0, 6.1136167611088625, 6.1136167611088625, 0.0],
#   [0.0, 2.5215358240279224, 2.5215358240279224, 0.0],
#   [0.0, 5.38994199476826, 5.38994199476826, 2.5215358240279224],
#   [0.0, 1.735594528398933, 1.735594528398933, 0.0],
#   [0.0, 0.41134719020154287, 0.41134719020154287, 0.0],
#   [0.0, 0.9947979526400732, 0.9947979526400732, 0.41134719020154287],
#   [0.0, 1.1131709722859213, 1.1131709722859213, 0.9947979526400732],
#   [0.0, 0.943263344064606, 0.943263344064606, 0.0],
#   [0.0, 1.8396397744808757, 1.8396397744808757, 0.943263344064606],
#   [1.1131709722859213,
#    2.3631775455439628,
#    2.3631775455439628,
#    1.8396397744808757],
#   [1.735594528398933, 4.26074011386541, 4.26074011386541, 2.3631775455439628],
#   [0.0, 8.705200408104995, 8.705200408104995, 4.26074011386541],
#   [5.38994199476826,
#    11.732585162302302,
#    11.732585162302302,
#    8.705200408104995],
#   [0.0, 0.7071632424174884, 0.7071632424174884, 0.0],
#   [0.0, 0.736900250421719, 0.736900250421719, 0.7071632424174884],
#   [0.0, 1.0372114027836854, 1.0372114027836854, 0.0],
#   [0.0, 1.2109830270116815, 1.2109830270116815, 1.0372114027836854],
#   [0.736900250421719,
#    1.3036462282468888,
#    1.3036462282468888,
#    1.2109830270116815],
#   [0.0, 1.3976508736315147, 1.3976508736315147, 0.0],
#   [0.0, 1.7926533525038457, 1.7926533525038457, 1.3976508736315147],
#   [0.0, 0.5295586703784229, 0.5295586703784229, 0.0],
#   [0.0, 0.6527221296598946, 0.6527221296598946, 0.5295586703784229],
#   [0.0, 0.5147892690482622, 0.5147892690482622, 0.0],
#   [0.0, 0.15392478308116397, 0.15392478308116397, 0.0],
#   [0.0, 0.24390168771648646, 0.24390168771648646, 0.0],
#   [0.0, 0.3810778235454624, 0.3810778235454624, 0.24390168771648646],
#   [0.15392478308116397,
#    0.690845428746004,
#    0.690845428746004,
#    0.3810778235454624],
#   [0.5147892690482622,
#    0.7643773837628931,
#    0.7643773837628931,
#    0.690845428746004],
#   [0.0, 0.4089524773323355, 0.4089524773323355, 0.0],
#   [0.0, 0.5895426790943754, 0.5895426790943754, 0.4089524773323355],
#   [0.0, 0.8136857168309038, 0.8136857168309038, 0.0],
#   [0.5895426790943754,
#    1.1012968126597578,
#    1.1012968126597578,
#    0.8136857168309038],
#   [0.7643773837628931,
#    1.4773266749772438,
#    1.4773266749772438,
#    1.1012968126597578],
#   [0.6527221296598946,
#    1.6279293076645829,
#    1.6279293076645829,
#    1.4773266749772438],
#   [0.0, 0.8947041728981955, 0.8947041728981955, 0.0],
#   [0.0, 0.6949248271207525, 0.6949248271207525, 0.0],
#   [0.0, 0.7974873979371312, 0.7974873979371312, 0.0],
#   [0.6949248271207525,
#    1.1345804138481943,
#    1.1345804138481943,
#    0.7974873979371312],
#   [0.8947041728981955, 1.82594890372188, 1.82594890372188, 1.1345804138481943],
#   [1.6279293076645829,
#    3.0666601849050905,
#    3.0666601849050905,
#    1.82594890372188],
#   [1.7926533525038457,
#    4.616656444199334,
#    4.616656444199334,
#    3.0666601849050905],
#   [1.3036462282468888,
#    4.9927385169968534,
#    4.9927385169968534,
#    4.616656444199334],
#   [0.0, 0.2696920874672715, 0.2696920874672715, 0.0],
#   [0.0, 0.43737012417171217, 0.43737012417171217, 0.2696920874672715],
#   [0.0, 0.40425874054016914, 0.40425874054016914, 0.0],
#   [0.0, 0.44764740174998263, 0.44764740174998263, 0.0],
#   [0.0, 0.4608763489717973, 0.4608763489717973, 0.0],
#   [0.44764740174998263,
#    0.6616222138095571,
#    0.6616222138095571,
#    0.4608763489717973],
#   [0.0, 0.7513177558957262, 0.7513177558957262, 0.6616222138095571],
#   [0.40425874054016914,
#    1.093698045317488,
#    1.093698045317488,
#    0.7513177558957262],
#   [0.43737012417171217,
#    1.7611054326204314,
#    1.7611054326204314,
#    1.093698045317488],
#   [0.0, 0.801736197713754, 0.801736197713754, 0.0],
#   [0.0, 0.9910141226285599, 0.9910141226285599, 0.801736197713754],
#   [0.0, 0.21968274022016698, 0.21968274022016698, 0.0],
#   [0.0, 0.40765148317021616, 0.40765148317021616, 0.21968274022016698],
#   [0.0, 0.21217604413471453, 0.21217604413471453, 0.0],
#   [0.0, 0.6175834219381735, 0.6175834219381735, 0.21217604413471453],
#   [0.40765148317021616,
#    0.7541585836637422,
#    0.7541585836637422,
#    0.6175834219381735],
#   [0.0, 0.34933512749100826, 0.34933512749100826, 0.0],
#   [0.0, 0.23609376782006447, 0.23609376782006447, 0.0],
#   [0.0, 0.31458005807728856, 0.31458005807728856, 0.23609376782006447],
#   [0.0, 0.7095009272938545, 0.7095009272938545, 0.31458005807728856],
#   [0.34933512749100826,
#    0.8323636162457985,
#    0.8323636162457985,
#    0.7095009272938545],
#   [0.7541585836637422,
#    1.398921597785276,
#    1.398921597785276,
#    0.8323636162457985],
#   [0.9910141226285599,
#    2.150116599912116,
#    2.150116599912116,
#    1.398921597785276],
#   [1.7611054326204314,
#    3.5572579504927377,
#    3.5572579504927377,
#    2.150116599912116],
#   [0.0, 0.54828334369571, 0.54828334369571, 0.0],
#   [0.0, 0.5226896792126101, 0.5226896792126101, 0.0],
#   [0.0, 0.700137335437712, 0.700137335437712, 0.5226896792126101],
#   [0.54828334369571,
#    1.1509802030921976,
#    1.1509802030921976,
#    0.700137335437712],
#   [0.0, 0.6527001866575526, 0.6527001866575526, 0.0],
#   [0.0, 1.014696455390511, 1.014696455390511, 0.0],
#   [0.0, 1.2969684843448694, 1.2969684843448694, 1.014696455390511],
#   [0.6527001866575526,
#    1.7810920896820195,
#    1.7810920896820195,
#    1.2969684843448694],
#   [1.1509802030921976,
#    2.5037279837782105,
#    2.5037279837782105,
#    1.7810920896820195],
#   [0.0, 0.48594222126103853, 0.48594222126103853, 0.0],
#   [0.0, 0.3858827539379468, 0.3858827539379468, 0.0],
#   [0.0, 0.6666942339703975, 0.6666942339703975, 0.3858827539379468],
#   [0.48594222126103853,
#    0.7001551773442388,
#    0.7001551773442388,
#    0.6666942339703975],
#   [0.0, 0.42942169280614695, 0.42942169280614695, 0.0],
#   [0.0, 0.6335930182607608, 0.6335930182607608, 0.42942169280614695],
#   [0.0, 0.4186031247339583, 0.4186031247339583, 0.0],
#   [0.0, 0.5362968833114152, 0.5362968833114152, 0.4186031247339583],
#   [0.0, 0.32860237370881545, 0.32860237370881545, 0.0],
#   [0.0, 0.20992691982100206, 0.20992691982100206, 0.0],
#   [0.0, 0.43665594067427516, 0.43665594067427516, 0.20992691982100206],
#   [0.32860237370881545,
#    0.7379127306647334,
#    0.7379127306647334,
#    0.43665594067427516],
#   [0.5362968833114152,
#    1.0293277037699151,
#    1.0293277037699151,
#    0.7379127306647334],
#   [0.6335930182607608,
#    1.064357729774167,
#    1.064357729774167,
#    1.0293277037699151],
#   [0.7001551773442388,
#    1.6278341872254327,
#    1.6278341872254327,
#    1.064357729774167],
#   [0.0, 0.3993010687241183, 0.3993010687241183, 0.0],
#   [0.0, 0.6221916144560301, 0.6221916144560301, 0.0],
#   [0.3993010687241183,
#    0.8200879428501845,
#    0.8200879428501845,
#    0.6221916144560301],
#   [0.0, 0.4359996542934685, 0.4359996542934685, 0.0],
#   [0.0, 0.819803852997222, 0.819803852997222, 0.0],
#   [0.4359996542934685,
#    1.133624602412897,
#    1.133624602412897,
#    0.819803852997222],
#   [0.8200879428501845,
#    1.7222447490177504,
#    1.7222447490177504,
#    1.133624602412897],
#   [1.6278341872254327,
#    2.793878905072425,
#    2.793878905072425,
#    1.7222447490177504],
#   [2.5037279837782105,
#    4.329407034046887,
#    4.329407034046887,
#    2.793878905072425],
#   [3.5572579504927377,
#    6.759572801811223,
#    6.759572801811223,
#    4.329407034046887],
#   [4.9927385169968534,
#    12.65119572759831,
#    12.65119572759831,
#    6.759572801811223],
#   [11.732585162302302,
#    14.210237915428428,
#    14.210237915428428,
#    12.65119572759831],
#   [6.1136167611088625,
#    17.483323819614043,
#    17.483323819614043,
#    14.210237915428428],
#   [7.2562756344701596,
#    21.722671293085273,
#    21.722671293085273,
#    17.483323819614043],
#   [18.063393981628494,
#    27.492584331672614,
#    27.492584331672614,
#    21.722671293085273],
#   [24.67940341058281,
#    32.00714019421446,
#    32.00714019421446,
#    27.492584331672614]],
#  'ivl': ['183',
#   '86',
#   '47',
#   '61',
#   '85',
#   '333',
#   '312',
#   '343',
#   '155',
#   '304',
#   '351',
#   '43',
#   '205',
#   '173',
#   '353',
#   '145',
#   '437',
#   '77',
#   '331',
#   '216',
#   '49',
#   '163',
#   '201',
#   '65',
#   '211',
#   '92',
#   '251',
#   '171',
#   '28',
#   '45',
#   '56',
#   '319',
#   '266',
#   '264',
#   '418',
#   '9',
#   '101',
#   '215',
#   '315',
#   '189',
#   '16',
#   '175',
#   '57',
#   '293',
#   '416',
#   '94',
#   '305',
#   '193',
#   '357',
#   '303',
#   '170',
#   '81',
#   '159',
#   '53',
#   '182',
#   '156',
#   '245',
#   '10',
#   '346',
#   '160',
#   '341',
#   '214',
#   '302',
#   '420',
#   '106',
#   '340',
#   '42',
#   '188',
#   '111',
#   '268',
#   '37',
#   '426',
#   '165',
#   '100',
#   '63',
#   '107',
#   '109',
#   '38',
#   '309',
#   '209',
#   '349',
#   '46',
#   '306',
#   '200',
#   '301',
#   '407',
#   '297',
#   '408',
#   '19',
#   '60',
#   '323',
#   '424',
#   '423',
#   '434',
#   '25',
#   '6',
#   '84',
#   '123',
#   '0',
#   '5',
#   '281',
#   '144',
#   '248',
#   '185',
#   '178',
#   '256',
#   '153',
#   '128',
#   '231',
#   '379',
#   '108',
#   '137',
#   '272',
#   '66',
#   '96',
#   '345',
#   '35',
#   '412',
#   '44',
#   '221',
#   '48',
#   '298',
#   '417',
#   '207',
#   '62',
#   '164',
#   '342',
#   '172',
#   '208',
#   '158',
#   '197',
#   '102',
#   '213',
#   '136',
#   '187',
#   '376',
#   '430',
#   '396',
#   '82',
#   '1',
#   '244',
#   '166',
#   '365',
#   '7',
#   '415',
#   '59',
#   '74',
#   '254',
#   '358',
#   '265',
#   '384',
#   '24',
#   '202',
#   '409',
#   '17',
#   '372',
#   '411',
#   '2',
#   '218',
#   '410',
#   '419',
#   '161',
#   '429',
#   '212',
#   '438',
#   '168',
#   '361',
#   '238',
#   '206',
#   '369',
#   '194',
#   '80',
#   '308',
#   '375',
#   '135',
#   '192',
#   '134',
#   '146',
#   '133',
#   '224',
#   '69',
#   '199',
#   '366',
#   '147',
#   '260',
#   '388',
#   '399',
#   '78',
#   '236',
#   '246',
#   '374',
#   '286',
#   '405',
#   '228',
#   '275',
#   '97',
#   '98',
#   '131',
#   '154',
#   '184',
#   '203',
#   '299',
#   '355',
#   '327',
#   '352',
#   '439',
#   '34',
#   '362',
#   '359',
#   '320',
#   '392',
#   '428',
#   '233',
#   '235',
#   '167',
#   '348',
#   '295',
#   '363',
#   '117',
#   '139',
#   '51',
#   '8',
#   '55',
#   '350',
#   '227',
#   '250',
#   '364',
#   '367',
#   '219',
#   '344',
#   '31',
#   '386',
#   '121',
#   '291',
#   '274',
#   '79',
#   '290',
#   '280',
#   '378',
#   '271',
#   '433',
#   '151',
#   '391',
#   '174',
#   '204',
#   '95',
#   '317',
#   '75',
#   '118',
#   '237',
#   '404',
#   '322',
#   '296',
#   '152',
#   '157',
#   '242',
#   '356',
#   '360',
#   '368',
#   '83',
#   '387',
#   '113',
#   '110',
#   '385',
#   '105',
#   '150',
#   '307',
#   '162',
#   '120',
#   '114',
#   '217',
#   '225',
#   '104',
#   '132',
#   '116',
#   '318',
#   '15',
#   '11',
#   '394',
#   '269',
#   '220',
#   '122',
#   '247',
#   '191',
#   '288',
#   '27',
#   '58',
#   '336',
#   '383',
#   '64',
#   '292',
#   '270',
#   '390',
#   '223',
#   '329',
#   '414',
#   '257',
#   '263',
#   '314',
#   '198',
#   '321',
#   '330',
#   '119',
#   '313',
#   '389',
#   '395',
#   '90',
#   '26',
#   '115',
#   '50',
#   '169',
#   '316',
#   '148',
#   '186',
#   '21',
#   '326',
#   '400',
#   '88',
#   '143',
#   '337',
#   '222',
#   '261',
#   '3',
#   '278',
#   '249',
#   '130',
#   '229',
#   '397',
#   '99',
#   '398',
#   '68',
#   '179',
#   '252',
#   '339',
#   '72',
#   '76',
#   '93',
#   '325',
#   '23',
#   '71',
#   '87',
#   '181',
#   '103',
#   '125',
#   '176',
#   '259',
#   '239',
#   '282',
#   '284',
#   '39',
#   '258',
#   '425',
#   '310',
#   '431',
#   '413',
#   '277',
#   '338',
#   '196',
#   '427',
#   '435',
#   '354',
#   '195',
#   '230',
#   '70',
#   '381',
#   '126',
#   '371',
#   '328',
#   '91',
#   '287',
#   '283',
#   '393',
#   '406',
#   '73',
#   '190',
#   '22',
#   '40',
#   '112',
#   '334',
#   '240',
#   '401',
#   '436',
#   '124',
#   '273',
#   '285',
#   '289',
#   '52',
#   '29',
#   '129',
#   '370',
#   '377',
#   '142',
#   '33',
#   '311',
#   '262',
#   '32',
#   '432',
#   '402',
#   '232',
#   '422',
#   '255',
#   '380',
#   '149',
#   '324',
#   '54',
#   '241',
#   '13',
#   '67',
#   '347',
#   '14',
#   '335',
#   '141',
#   '403',
#   '253',
#   '12',
#   '382',
#   '138',
#   '243',
#   '177',
#   '180',
#   '373',
#   '294',
#   '41',
#   '140',
#   '30',
#   '18',
#   '127',
#   '20',
#   '300',
#   '226',
#   '279',
#   '421',
#   '210',
#   '332',
#   '234',
#   '267',
#   '89',
#   '276',
#   '4',
#   '36'],
#  'leaves': [183,
#   86,
#   47,
#   61,
#   85,
#   333,
#   312,
#   343,
#   155,
#   304,
#   351,
#   43,
#   205,
#   173,
#   353,
#   145,
#   437,
#   77,
#   331,
#   216,
#   49,
#   163,
#   201,
#   65,
#   211,
#   92,
#   251,
#   171,
#   28,
#   45,
#   56,
#   319,
#   266,
#   264,
#   418,
#   9,
#   101,
#   215,
#   315,
#   189,
#   16,
#   175,
#   57,
#   293,
#   416,
#   94,
#   305,
#   193,
#   357,
#   303,
#   170,
#   81,
#   159,
#   53,
#   182,
#   156,
#   245,
#   10,
#   346,
#   160,
#   341,
#   214,
#   302,
#   420,
#   106,
#   340,
#   42,
#   188,
#   111,
#   268,
#   37,
#   426,
#   165,
#   100,
#   63,
#   107,
#   109,
#   38,
#   309,
#   209,
#   349,
#   46,
#   306,
#   200,
#   301,
#   407,
#   297,
#   408,
#   19,
#   60,
#   323,
#   424,
#   423,
#   434,
#   25,
#   6,
#   84,
#   123,
#   0,
#   5,
#   281,
#   144,
#   248,
#   185,
#   178,
#   256,
#   153,
#   128,
#   231,
#   379,
#   108,
#   137,
#   272,
#   66,
#   96,
#   345,
#   35,
#   412,
#   44,
#   221,
#   48,
#   298,
#   417,
#   207,
#   62,
#   164,
#   342,
#   172,
#   208,
#   158,
#   197,
#   102,
#   213,
#   136,
#   187,
#   376,
#   430,
#   396,
#   82,
#   1,
#   244,
#   166,
#   365,
#   7,
#   415,
#   59,
#   74,
#   254,
#   358,
#   265,
#   384,
#   24,
#   202,
#   409,
#   17,
#   372,
#   411,
#   2,
#   218,
#   410,
#   419,
#   161,
#   429,
#   212,
#   438,
#   168,
#   361,
#   238,
#   206,
#   369,
#   194,
#   80,
#   308,
#   375,
#   135,
#   192,
#   134,
#   146,
#   133,
#   224,
#   69,
#   199,
#   366,
#   147,
#   260,
#   388,
#   399,
#   78,
#   236,
#   246,
#   374,
#   286,
#   405,
#   228,
#   275,
#   97,
#   98,
#   131,
#   154,
#   184,
#   203,
#   299,
#   355,
#   327,
#   352,
#   439,
#   34,
#   362,
#   359,
#   320,
#   392,
#   428,
#   233,
#   235,
#   167,
#   348,
#   295,
#   363,
#   117,
#   139,
#   51,
#   8,
#   55,
#   350,
#   227,
#   250,
#   364,
#   367,
#   219,
#   344,
#   31,
#   386,
#   121,
#   291,
#   274,
#   79,
#   290,
#   280,
#   378,
#   271,
#   433,
#   151,
#   391,
#   174,
#   204,
#   95,
#   317,
#   75,
#   118,
#   237,
#   404,
#   322,
#   296,
#   152,
#   157,
#   242,
#   356,
#   360,
#   368,
#   83,
#   387,
#   113,
#   110,
#   385,
#   105,
#   150,
#   307,
#   162,
#   120,
#   114,
#   217,
#   225,
#   104,
#   132,
#   116,
#   318,
#   15,
#   11,
#   394,
#   269,
#   220,
#   122,
#   247,
#   191,
#   288,
#   27,
#   58,
#   336,
#   383,
#   64,
#   292,
#   270,
#   390,
#   223,
#   329,
#   414,
#   257,
#   263,
#   314,
#   198,
#   321,
#   330,
#   119,
#   313,
#   389,
#   395,
#   90,
#   26,
#   115,
#   50,
#   169,
#   316,
#   148,
#   186,
#   21,
#   326,
#   400,
#   88,
#   143,
#   337,
#   222,
#   261,
#   3,
#   278,
#   249,
#   130,
#   229,
#   397,
#   99,
#   398,
#   68,
#   179,
#   252,
#   339,
#   72,
#   76,
#   93,
#   325,
#   23,
#   71,
#   87,
#   181,
#   103,
#   125,
#   176,
#   259,
#   239,
#   282,
#   284,
#   39,
#   258,
#   425,
#   310,
#   431,
#   413,
#   277,
#   338,
#   196,
#   427,
#   435,
#   354,
#   195,
#   230,
#   70,
#   381,
#   126,
#   371,
#   328,
#   91,
#   287,
#   283,
#   393,
#   406,
#   73,
#   190,
#   22,
#   40,
#   112,
#   334,
#   240,
#   401,
#   436,
#   124,
#   273,
#   285,
#   289,
#   52,
#   29,
#   129,
#   370,
#   377,
#   142,
#   33,
#   311,
#   262,
#   32,
#   432,
#   402,
#   232,
#   422,
#   255,
#   380,
#   149,
#   324,
#   54,
#   241,
#   13,
#   67,
#   347,
#   14,
#   335,
#   141,
#   403,
#   253,
#   12,
#   382,
#   138,
#   243,
#   177,
#   180,
#   373,
#   294,
#   41,
#   140,
#   30,
#   18,
#   127,
#   20,
#   300,
#   226,
#   279,
#   421,
#   210,
#   332,
#   234,
#   267,
#   89,
#   276,
#   4,
#   36],
#  'color_list': ['g',
#   'g',
#   'g',
#   'g',
#   'b',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'r',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'c',
#   'b',
#   'b']}

# %%
# To apply hierarchical in product, we use AgglomerativeClustering
# in sklearn package instead of scipy
# so import it first
# Your code here

# Create AgglomerativeClustering model with n_clusters equals to the number of cluster
# you think it's the best one
cluster = # Your code here

# fit model with scaled data
# Your code here
# Out:
# array([2, 2, 2, 4, 0, 2, 2, 2, 4, 2, 2, 4, 0, 0, 0, 4, 2, 2, 0, 2, 0, 4,
#        0, 0, 2, 2, 4, 4, 5, 0, 0, 4, 0, 0, 4, 2, 0, 2, 2, 0, 0, 0, 2, 5,
#        2, 5, 2, 1, 2, 5, 4, 4, 0, 2, 0, 4, 5, 2, 4, 2, 2, 1, 2, 2, 4, 5,
#        2, 0, 4, 4, 0, 0, 4, 0, 2, 4, 4, 5, 4, 4, 4, 2, 2, 4, 2, 1, 1, 0,
#        4, 0, 4, 0, 5, 0, 2, 4, 2, 4, 4, 4, 2, 2, 2, 0, 4, 4, 2, 2, 2, 2,
#        4, 2, 0, 4, 4, 4, 4, 4, 4, 4, 4, 4, 4, 2, 0, 0, 0, 0, 2, 0, 4, 4,
#        4, 4, 4, 4, 2, 2, 0, 4, 0, 0, 0, 4, 2, 5, 4, 4, 4, 0, 4, 4, 4, 2,
#        4, 5, 2, 4, 2, 2, 2, 4, 4, 5, 2, 2, 2, 4, 4, 4, 2, 5, 2, 5, 4, 2,
#        0, 0, 2, 4, 0, 0, 2, 3, 4, 2, 4, 2, 2, 2, 0, 4, 4, 2, 4, 0, 0, 2,
#        4, 4, 2, 5, 2, 4, 4, 5, 4, 2, 2, 2, 0, 5, 4, 2, 2, 2, 5, 4, 2, 4,
#        4, 2, 4, 4, 4, 4, 0, 4, 4, 4, 0, 2, 0, 4, 0, 4, 4, 4, 4, 0, 0, 0,
#        4, 0, 2, 2, 4, 4, 2, 4, 4, 5, 4, 0, 2, 0, 2, 4, 0, 0, 4, 4, 0, 4,
#        2, 2, 2, 0, 2, 4, 4, 4, 2, 0, 4, 4, 0, 0, 4, 0, 4, 2, 0, 0, 0, 0,
#        4, 0, 4, 0, 4, 4, 4, 2, 0, 4, 4, 2, 2, 4, 0, 2, 2, 2, 5, 2, 2, 4,
#        4, 2, 0, 0, 5, 4, 4, 2, 4, 4, 4, 5, 4, 4, 4, 2, 0, 0, 4, 4, 0, 4,
#        4, 5, 0, 1, 0, 0, 4, 4, 0, 4, 2, 2, 2, 5, 4, 2, 2, 0, 4, 2, 4, 5,
#        4, 5, 0, 4, 4, 2, 2, 4, 4, 4, 4, 4, 4, 2, 4, 4, 4, 4, 0, 0, 2, 0,
#        4, 4, 2, 0, 4, 2, 0, 0, 0, 4, 2, 4, 4, 4, 4, 4, 4, 4, 4, 0, 4, 4,
#        2, 4, 4, 4, 4, 0, 0, 0, 4, 4, 0, 2, 2, 2, 4, 2, 2, 0, 4, 2, 2, 2,
#        2, 4, 2, 0, 0, 2, 2, 0, 2, 0, 4, 4, 2, 0, 0, 4, 2, 0, 0, 5, 4, 4])

# %%
# apply hierarchical in product, we use AgglomerativeClustering
# My code here
from sklearn.cluster import AgglomerativeClustering
agg_model = AgglomerativeClustering(n_clusters=6, linkage='ward').fit(data_dropped)
agg_model.labels_
# Out:
# array([5, 5, 5, 3, 1, 5, 3, 5, 3, 4, 5, 3, 1, 1, 1, 3, 5, 3, 1, 5, 1, 3,
#        1, 5, 1, 1, 3, 1, 4, 0, 1, 3, 1, 1, 3, 5, 1, 5, 4, 0, 1, 1, 5, 4,
#        5, 4, 4, 2, 5, 4, 3, 3, 0, 5, 1, 3, 4, 5, 1, 5, 5, 2, 5, 5, 3, 4,
#        3, 1, 3, 3, 1, 1, 3, 1, 5, 1, 3, 4, 3, 3, 3, 5, 5, 1, 3, 2, 2, 0,
#        3, 1, 3, 3, 4, 3, 5, 3, 3, 3, 3, 3, 5, 5, 5, 0, 1, 1, 5, 5, 3, 4,
#        3, 5, 1, 1, 1, 3, 3, 3, 1, 3, 1, 3, 1, 5, 0, 0, 1, 1, 3, 0, 3, 3,
#        1, 3, 3, 3, 5, 3, 3, 3, 1, 1, 1, 3, 1, 4, 3, 3, 3, 1, 1, 3, 1, 3,
#        3, 4, 5, 1, 5, 5, 5, 1, 1, 4, 5, 5, 5, 3, 3, 3, 5, 4, 3, 4, 3, 5,
#        0, 5, 5, 3, 1, 0, 5, 0, 3, 3, 3, 5, 5, 5, 1, 1, 3, 4, 3, 1, 1, 5,
#        3, 3, 4, 4, 1, 3, 3, 4, 3, 3, 3, 4, 1, 4, 3, 5, 5, 5, 4, 1, 5, 3,
#        1, 5, 3, 3, 3, 3, 1, 3, 3, 3, 3, 3, 1, 3, 1, 3, 3, 1, 3, 0, 1, 1,
#        1, 3, 5, 5, 3, 1, 1, 3, 3, 4, 3, 1, 5, 1, 5, 3, 0, 0, 3, 3, 1, 3,
#        5, 5, 4, 1, 5, 1, 3, 3, 3, 0, 3, 3, 1, 3, 3, 1, 3, 5, 0, 1, 0, 0,
#        3, 1, 1, 0, 3, 3, 3, 5, 1, 3, 1, 5, 5, 3, 1, 4, 5, 5, 4, 5, 4, 1,
#        3, 5, 3, 1, 4, 3, 3, 5, 3, 3, 3, 4, 3, 3, 1, 1, 1, 0, 3, 3, 1, 3,
#        3, 4, 1, 2, 1, 1, 1, 3, 3, 3, 5, 5, 3, 4, 3, 3, 5, 1, 3, 4, 3, 4,
#        3, 4, 3, 3, 1, 4, 5, 3, 1, 3, 3, 3, 3, 5, 3, 3, 1, 3, 0, 1, 3, 1,
#        3, 3, 5, 0, 3, 5, 1, 1, 1, 3, 5, 3, 3, 1, 3, 3, 3, 3, 3, 1, 3, 3,
#        5, 3, 3, 3, 3, 1, 1, 1, 1, 3, 1, 4, 5, 3, 3, 3, 5, 3, 3, 5, 5, 5,
#        4, 3, 5, 1, 1, 1, 1, 3, 5, 1, 3, 3, 5, 3, 1, 3, 1, 1, 0, 4, 3, 3])

# %%
# Plot out result using scatter using the first 2 components of PCA
# Your code here

# %%
# Have no idea :(

# %% [markdown]
# ## Great job!!!
